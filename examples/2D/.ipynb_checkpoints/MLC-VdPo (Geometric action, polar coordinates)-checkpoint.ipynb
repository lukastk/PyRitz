# %% [markdown]
# # Multi-limit cycle Van der Pol oscillator (MLC-VdPo)
#
# **Lagrangian:** Geometric Action
# <br>
# **Implementation:** Python
#
# **System:**
#
# $ \begin{cases}
# du = (u - u^3 - \beta u v^2)\ dt + \sqrt{\epsilon}\ dW_u \\
# dv = -(1 + u^2) v\ dt + \sqrt{\epsilon}\ dW_v
# \end{cases}$

# %%
sfdir = !pwd
sfdir = "/".join(sfdir[0].split("/")[:-3]) + "/"
import sys
sys.path.insert(0, sfdir+'pyritz/')

import pyritz
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import nlopt

# %% [markdown]
# ## System

# %% [markdown]
# ### Parameters

# %% [markdown]
# System parameters are defined here. All system parameter variables are prefaced with "m_", with the exception of `dim` which is the dimension of the system.

# %%
dim = 2

m_mu = 0.1
m_alpha = 0.144
m_beta = 0.005

# %% [markdown]
# ### Dynamics
#
# `system_a` is the drift term of the system. It's used for plotting stream-plots, as well as finding fixed points of the deterministic system.
#
# `lagrangian` is the Lagrangian of the system. The Lagrangian used is the Geometric Action lagrangian (Heymann and Vanden-Eijnden), defined as
#
# $$
# L(x, \dot x) = |\dot x| |a(x)| - \dot x \cdot a(x)
# $$
#
# for any general Ito diffusion of the form
#
# $$
# dX = a(X)dt + \sqrt{\epsilon} dW.
# $$
#
# The function also computes the partial derivatives of the Lagrangian, which are used for gradient optimisation. This can be enabled/disabled by setting the *args* argument to True/False. The partial derivatives of the geometric lagrangian are
#
# $$\begin{aligned}
# \frac{\partial L}{\partial x} & = \nabla a( x ) \cdot \left( |\dot x| \hat{a}(x) - \dot x \right) \\
# \frac{\partial L}{\partial \dot x} & = |a(x)| \hat{\dot{x}} - a(x)
# \end{aligned}$$
#
# An important property of the geometric action is that it is time-reparameterisation invariant, meaning that $x$ can be replaced by any other path that shares the same *graph*.

# %% [markdown]
# #### Notes on the Maier-Stein system
#
# Let $(\nabla a)_{ij} = \frac{\partial a_i}{\partial x_j}$, where $x = (u, v)$, then
#
# $$
# \nabla a = \begin{pmatrix}
#     1 - 3 u^2 - \beta v^2 &  -2 u v \\
#     - 2 \beta u v & - (1 + u^2)
# \end{pmatrix}
# $$

# %%
system_a(5,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bece3cdff2ca> in <module>
# ----> 1 system_a(5,2)
#
# NameError: name 'system_a' is not defined

# %%
def system_a_cartesian(x, y):
    return np.array([
        m_mu*( 1 - y**2 + m_alpha*y**4 - m_beta*y**6 )*x - y,
        x
    ])

def system_a(r, th):
    pr = 1 - (r*np.sin(th))**2 + m_alpha*(r*np.sin(th))**4 - m_beta*(r*np.sin(th))**6
    
    return np.array([
        r*m_mu*np.cos(th)**2 * pr,
        1 - m_mu*np.cos(th)*np.sin(th)*pr
    ])

def lagrangian(ls, dxls, dvls, fvals, ts, args):
    compute_gradient = args
    
    xs, dxs = fvals
    rs, ths = xs[:, 0], xs[:, 1]
    drs, dths = dxs[:, 0], dxs[:, 1]
    
    prs = 1 - (rs*np.sin(ths))**2 + m_alpha*(rs*np.sin(ths))**4 - m_beta*(rs*np.sin(ths))**6
    ars = rs*m_mu*rs*np.cos(ths)**2 * prs
    aths = 1 - m_mu*np.cos(ths)*np.sin(ths)*prs
    aas = np.array( [ars, aths] )
    
    dxs_norm = np.linalg.norm(dxs, axis=1)
    a_norm = np.sqrt(ars**2 + aths**2)
    dxs_dot_a = ars*dxs[:,0] + aths*dxs[:, 1]
    
    ls[:] = dxs_norm * a_norm - dxs_dot_a
    
    # Compute gradient
    
    if compute_gradient:

        ## Compute dL/dx

        da = np.zeros( (dim, dim, len(ts)) )
        da[0,0, :] = m_mu*np.cos(ths)**2*(1 - 3*rs**2*np.sin(ths)**2 + 5*rs**4*m_alpha*np.sin(ths)**4 - 7*rs**6*m_beta*np.sin(ths)**6)
        da[0,1, :] = -2*rs*m_mu*np.cos(ths)*np.sin(ths)*(1 - rs**2*np.sin(ths)**2 + rs**4*m_alpha*np.sin(ths)**4 -     rs**6*m_beta*np.sin(ths)**6 +     np.cos(ths)**2*(rs**2 - 2*rs**4*m_alpha*np.sin(ths)**2 +        3*rs**6*m_beta*np.sin(ths)**4))
        da[1,0, :] = m_mu*(rs*np.sin(ths)**2 - 2*rs**3*m_alpha*np.sin(ths)**4 + 3*rs**5*m_beta*np.sin(ths)**6)*np.sin(2*ths)
        da[1,1, :] = m_mu*(np.sin(ths)**2 - rs**2*np.sin(ths)**4 + rs**4*m_alpha*np.sin(ths)**6 -  rs**6*m_beta*np.sin(ths)**8 + np.cos(ths)**2*(-1 + 3*rs**2*np.sin(ths)**2 - 5*rs**4*m_alpha*np.sin(ths)**4 + 7*rs**6*m_beta*np.sin(ths)**6))
        
        a_normalized = aas/a_norm

        a_normalized[:, np.where(a_norm==0)] = 0 # Set zero-norm vectors to 0

        for i in range(dxls.shape[0]):
            dxls[i, :] = da[:,:,i].dot( dxs_norm[i]*a_normalized[:,i] - dxs[i,:])

        ## Compute dL/dv

        dxs_2 = (dxs.T*(a_norm/dxs_norm)).T
        dxs_2[ np.where(dxs_norm==0),:] = 0

        dvls[:] = dxs_2 - aas.T

# %% [markdown]
# ### Interpolation of the first loop of the unstable limit cycle

# %%
xs_l = np.array(
    [3.96226, 3.97547, 3.96241, 3.73778, 3.08518, 2.04073, 0.603525, \
-1.20436, -2.90251, -3.76111, -3.89842, -2.77813, -1.20244, 0.559773, \
2.14814, 3.15897, 3.62325, 3.84815, 3.94184, 3.96226]
)

ys_l = np.array([
    0., 0.170101, 0.676595, 1.48368, 2.4589, 3.36405, 3.91472, 3.78006, \
2.74449, 1.00561, -1.02758, -2.77798, -3.76849, -3.92248, -3.36203, \
-2.41433, -1.4461, -0.666092, -0.169464, -0.000087234
])

Nm_l = 20
ts_l = pyritz.funcs.CollocationFF.get_chebyshev_nodes(Nm_l)
ts_l
# Out:
# array([-1.        , -0.9863613 , -0.94581724, -0.87947375, -0.78914051,
#        -0.67728157, -0.54694816, -0.40169542, -0.24548549, -0.08257935,
#         0.08257935,  0.24548549,  0.40169542,  0.54694816,  0.67728157,
#         0.78914051,  0.87947375,  0.94581724,  0.9863613 ,  1.        ])

# %%
import scipy

intp_l = scipy.interpolate.BarycentricInterpolator(ts_l)

intp_l.set_yi(np.vstack( [xs_l, ys_l] ).T)

# %%
ts = np.linspace(-1, 1, 100)
xs = intp_l(ts)

plt.plot(xs[:,0], xs[:,1])

X, Y = np.meshgrid(np.linspace(-6,6,128), np.linspace(-6,6,128))
vx,vy=system_a_cartesian(X,Y);
plt.streamplot(X,Y, vx, vy, density=1.7, linewidth=.6, color='gray');
plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(7, 7)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Optimisation

# %% [markdown]
# ### Gradient-free optimisation

# %% [markdown]
# Inner: 2.65
#
# Outer: 4.86
#
# Unstable: 3.962-3.963

# %%
x_start = np.array([3.97, 0])
x_end = np.array([4, 10])
#x_end = np.array([3.999, 0])

Nm = 8
Nq = Nm*10

m0 = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm)

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1)

quad_scheme = pyritz.quads.Q_clenshaw_curtis

compute_gradient=False
act = pyritz.Action(dim, ff, lagrangian, Nq, quad_scheme, lagrangian_args=compute_gradient)

ub = np.full(dim*Nm, np.inf)
lb = np.full(dim*Nm, -np.inf)

tol = 0#1e-10

for i in range(dim):
    ub[i*Nm] = x_start[i] + tol
    lb[i*Nm] = x_start[i] - tol
    ub[Nm-1 + i*Nm] = x_end[i] + tol
    lb[Nm-1 + i*Nm] = x_end[i] - tol
    
ub[2*Nm-1]= np.inf
lb[2*Nm-1]= -np.inf

def get_action(m, grad):
    if grad.size > 0:
        grad[0] = grad[Nm] = grad[Nm-1] = 0 
        return act.compute(m, grad)
    else:
        return act.compute(m)

opt = nlopt.opt(nlopt.LN_NEWUOA, np.size(m0))
opt.set_lower_bounds(lb)
opt.set_upper_bounds(ub)
opt.set_min_objective(get_action)
opt.set_xtol_rel(1e-12)
opt.set_maxeval(5000)
m = opt.optimize(m0)

print(act.compute(m0))
print(act.compute(m))
# Out:
# /store/SOFT/ltk26/dev/softbridge/pyritz/pyritz/funcs/collocation_ff.py:163: RuntimeWarning: divide by zero encountered in double_scalars
#   s += omegas[k] / (ts[i] - self.chebyshev_ts[k] )
# 2.1431402053775885
# 0.6402401704527221

# %%
x_start = np.array([3.964,0])
x_end_t = -1
#x_end = intp_l(x_end_t)
x_end = np.array([3.965, 1])

Nm = 14
Nq = Nm*10

m0 = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm,
                                    exclude_start_point=True, exclude_end_point=True)
m0 += np.random.random( m0.size )/100

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1,
                               fixed_start_point=x_start,
                               fixed_end_point=x_end)

quad_scheme = pyritz.quads.Q_clenshaw_curtis

compute_gradient=False
act = pyritz.Action(dim, ff, lagrangian, Nq, quad_scheme, lagrangian_args=compute_gradient)

def get_action(m, grad):
    return act.compute(m)

opt = nlopt.opt(nlopt.LN_NEWUOA, np.size(m0))
opt.set_min_objective(get_action)
opt.set_xtol_rel(1e-12)
opt.set_maxeval(5000)
m = opt.optimize(m0)

print(act.compute(m0))
print(act.compute(m))
# Out:
# 0.29658175136637166
# 0.008111626398464354

# %%
x_start = np.array([3.964,0])
x_end_t = -1
#x_end = intp_l(x_end_t)
x_end = np.array([4.1, 0.5])

Nm = 5
Nq = Nm*10

m0_path = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm,
                                    exclude_start_point=True, exclude_end_point=True)
m0_path += np.random.random( m0_path.size )/100

m0 = np.concatenate(( m0_path, [x_end[1]] ))

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1,
                               fixed_start_point=x_start,
                               fixed_end_point=x_end)

quad_scheme = pyritz.quads.Q_clenshaw_curtis

compute_gradient=False
act = pyritz.Action(dim, ff, lagrangian, Nq, quad_scheme, lagrangian_args=compute_gradient)

def get_action(m, grad):
    thf = m[-1]
    m_path = m[:-1]
    x_end[1] = thf
    
    ff.set_fixed_end_point(x_end)
    
    return act.compute(m_path)

opt = nlopt.opt(nlopt.LN_NEWUOA, np.size(m0))
opt.set_min_objective(get_action)
opt.set_xtol_rel(1e-12)
opt.set_maxeval(5000)
m = opt.optimize(m0)

print(act.compute(m0_path))
print(act.compute(m[:-1]))
# Out:
# 0.21825225157659925
# 5.072089992550044e-10

# %% [markdown]
# #### Instanton plot

# %%
def polar_to_cartesian(xs):
    rs, ths = xs[:, 0], xs[:, 1]
    
    rxs = rs * np.cos(ths)
    rys = rs * np.sin(ths)
    
    return np.vstack( [rxs, rys] ).T

ts = np.linspace(-1, 1, 1000)

paths = [
    (m0, "Initial"),
    (m, "Final")
]

for p in paths:
    _m, _mlabel = p
    xs, vs = ff.evaluate(_m[:-1], ts)
    plt.plot(xs[:,0], xs[:,1], label=_mlabel)

X, Y = np.meshgrid(np.linspace(3,5,128), np.linspace(0, 2.5 ,128))
vx,vy=system_a(X,Y);# vx=vx/np.sqrt(vx**2+vy**2); vy=vy/np.sqrt(vx**2+vy**2)
plt.streamplot(X,Y, vx, vy, density=1.7, linewidth=.6, color='gray');
plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(7, 7)

# %%
def polar_to_cartesian(xs):
    rs, ths = xs[:, 0], xs[:, 1]
    
    rxs = rs * np.cos(ths)
    rys = rs * np.sin(ths)
    
    return np.vstack( [rxs, rys] ).T

ts = np.linspace(-1, 1, 1000)

paths = [
    (m0, "Initial"),
    (m, "Final")
]

for p in paths:
    _m, _mlabel = p
    xs, vs = ff.evaluate(_m, ts)
    plt.plot(xs[:,0], xs[:,1], label=_mlabel)

X, Y = np.meshgrid(np.linspace(0,6,128), np.linspace(0, 2*np.pi ,128))
vx,vy=system_a(X,Y);
plt.streamplot(X,Y, vx, vy, density=1.7, linewidth=.6, color='gray');
plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(7, 7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-2b5664a0327a> in <module>
#      16 for p in paths:
#      17     _m, _mlabel = p
# ---> 18     xs, vs = ff.evaluate(_m, ts)
#      19     plt.plot(xs[:,0], xs[:,1], label=_mlabel)
#      20
#
# /store/SOFT/ltk26/dev/softbridge/pyritz/pyritz/funcs/collocation_ff.py in evaluate(self, m, ts)
#      64         # the creation of a new array.
#      65         m_size = int(m.size/self.dim)
# ---> 66         m_reshaped = m.reshape( (self.dim, m_size) ).T
#      67
#      68         # TODO: Make this better
#
# ValueError: cannot reshape array of size 29 into shape (2,14)

# %%
ts = np.linspace(-1, 1, 1000)

paths = [
    (m0, "Initial"),
    (m, "Final")
]

for p in paths:
    _m, _mlabel = p
    xs, vs = ff.evaluate(_m, ts)
    xs = polar_to_cartesian(xs)
    plt.plot(xs[:,0], xs[:,1], label=_mlabel)

X, Y = np.meshgrid(np.linspace(-6,6,128), np.linspace(-6, 6 ,128))
vx,vy=system_a_cartesian(X,Y);
plt.streamplot(X,Y, vx, vy, density=1.7, linewidth=.6, color='gray');
plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(7, 7)

# %% [markdown]
# ### Gradient optimisation

# %%
x_start = np.array([3,0])
x_end_t = -1
#x_end = intp_l(x_end_t)
x_end = np.array([3.5, 1])

Nm = 8
Nq = Nm*8

m0 = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm,
                                    exclude_start_point=True, exclude_end_point=True)

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1,
                               fixed_start_point=x_start,
                               fixed_end_point=x_end)

quad_scheme = pyritz.quads.Q_clenshaw_curtis

compute_gradient=True
act = pyritz.Action(dim, ff, lagrangian, Nq, quad_scheme, lagrangian_args=compute_gradient)

def get_action(m, grad):
    if grad.size > 0:
        return act.compute(m, grad)
    else:
        return act.compute(m)

opt = nlopt.opt(nlopt.LD_SLSQP, np.size(m0))
opt.set_min_objective(get_action)
opt.set_xtol_rel(1e-12)
m = opt.optimize(m0)

print(act.compute(m0))
print(act.compute(m))

# %%
ts = np.linspace(-1, 1, 1000)

paths = [
    (m0, "Initial"),
    (m, "Final")
]

for p in paths:
    _m, _mlabel = p
    xs, vs = ff.evaluate(_m, ts)
    xs = polar_to_cartesian(xs)
    plt.plot(xs[:,0], xs[:,1], label=_mlabel)

X, Y = np.meshgrid(np.linspace(-6,6,128), np.linspace(-6, 6 ,128))
vx,vy=system_a_cartesian(X,Y);
plt.streamplot(X,Y, vx, vy, density=1.7, linewidth=.6, color='gray');
plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(7, 7)

# %%
ts = np.linspace(-1, 1, 1000)

paths = [
    (m0, "Initial"),
    (m, "Final")
]

for p in paths:
    _m, _mlabel = p
    xs, vs = ff.evaluate(_m, ts)
    plt.plot(xs[:,0], xs[:,1], label=_mlabel)

X, Y = np.meshgrid(np.linspace(-1.2,1.2,64), np.linspace(-0.4,.4,64))
vx,vy=system_a(X,Y); vx=vx/np.sqrt(vx**2+vy**2); vy=vy/np.sqrt(vx**2+vy**2)
plt.streamplot(X,Y, vx, vy, density=1.7, linewidth=.6, color='gray');
plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(7, 7)

# %% [markdown]
# ## Iterative gradient optimisation

# %%
x_start = e_xa
x_end = e_xb

Nms = np.array( [8, 9, 10] ).astype(int)
Nqs = Nms*10

m0 = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nms[0],
                                    exclude_start_point=True, exclude_end_point=True)
m0 += (-1 + 2*np.random.random(len(m0)))*0.1 # Add some noise to initial path

ff = pyritz.funcs.CollocationFF(Nms[0], dim, derivatives=1,
                               fixed_start_point=x_start,
                               fixed_end_point=x_end)
quad_scheme = pyritz.quads.Q_clenshaw_curtis
compute_gradient=True

res = pyritz.utils.minimize_action_iteratively(Nms, Nqs, x_start, x_end, lagrangian, ff, quad_scheme, m0,
                           nlopt.LD_SLSQP, lagrangian_args=compute_gradient,
                           xtol_rel=1e-12)

# %%
ts = np.linspace(-1, 1, 1000)

paths = [(m, "Nm=%s" % Nm, Nm) for m, S, Nm, Nq in res]

for p in paths:
    _m, _mlabel, _Nm = p
    xs, vs = ff.evaluate_at_order(_m, ts, _Nm)
    plt.plot(xs[:,0], xs[:,1], label=_mlabel)

X, Y = np.meshgrid(np.linspace(-1.2,1.2,64), np.linspace(-0.4,.4,64))
vx,vy=system_a(X,Y); vx=vx/np.sqrt(vx**2+vy**2); vy=vy/np.sqrt(vx**2+vy**2)
plt.streamplot(X,Y, vx, vy, density=1.7, linewidth=.6, color='gray');
plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(7, 6)

# %% [markdown]
# ## Quasipotential

# %%
def m0_provider(x_start, x_end, Nm):
    ff.set_fixed_end_point(x_end)

    m0 = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm,
                                        exclude_start_point=True, exclude_end_point=True)
    if np.allclose(x_end, e_xb):
        m0 += (-1 + 2*np.random.random(len(m0)))*0.1 # Add some noise to initial path
    return m0

x_start = e_xa
x_end = e_xb

Nmn       = 8
Nq = Nm*10

qp_width = 5
qp_height = 5
xs = np.linspace(-1.2, 1.2, qp_width)
ys = np.linspace(-0.4,0.4, qp_height)

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1,
                               fixed_start_point=x_start,
                               fixed_end_point=x_end)
quad_scheme = pyritz.quads.Q_clenshaw_curtis
compute_gradient=True

qp = pyritz.utils.compute_quasipotential(xs, ys, Nm, Nq, x_start, lagrangian, ff, quad_scheme,
                      m0_provider, nlopt.LD_MMA, lagrangian_args=compute_gradient, xtol_rel=1e-12, maxeval=5000)
