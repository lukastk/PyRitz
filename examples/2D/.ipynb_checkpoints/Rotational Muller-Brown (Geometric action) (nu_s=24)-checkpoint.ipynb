# %% [markdown]
# # Rotational Muller-Brown
#
# **Lagrangian:** Geometric Action
# <br>
# **Implementation:** Python
#
# **System:**
#
# Let $\mathbf{r}$ and $\theta$ be the positional and rotation coordinates respectively, and let $\mathbf{x} = (\mathbf{r}, \theta)$. The Muller-Brown drift term is
#
# $$
# \begin{aligned}
# U(\mathbf{r}) & = \sum_{i=1}^4 u^{(i)} \\
# u^{(i)} & = A^{(i)} \exp \left\{ (\mathbf{r} - \mathbf{r}^{(i)})^T M^{(i)} (\mathbf{r} - \mathbf{r}^{(i)}) \right\} \\
# \mathbf{F}(\mathbf{r}) & = - \nabla U
# \end{aligned}
# $$
#
# and the system is defined as
#
# $$\begin{aligned}
# d\mathbf{r} & = \frac{1}{\gamma} \mathbf{F}dt + \frac{1}{\gamma} \nu_s \mathbf{p} + \frac{1}{\gamma} \sigma d\mathbf{W} \\
# d\theta & = \frac{1}{\gamma_R} \sigma_R\ d W_R
# \end{aligned}
# $$
#
# where
#
# $$
# \mathbf{p} = (\cos \theta, \sin \theta).
# $$
#
# Usually, we set $\gamma$, $\gamma_R$, $\sigma$ and $\sigma_R$ such that
#
# $$
# \begin{aligned}
# \gamma & = \gamma_R = 1 \\
# \frac{1}{\gamma} \sigma & = \frac{1}{\gamma_R} \sigma_R = I
# \end{aligned}
# $$

# %%
sfdir = !pwd
sfdir = "/".join(sfdir[0].split("/")[:-3]) + "/"
import sys
sys.path.insert(0, sfdir+'pyritz/')

import pyritz
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import nlopt

# %% [markdown]
# ## System

# %% [markdown]
# ### Parameters
#
# System parameters are defined here. All system parameter variables are prefaced with "m_", with the exception of `dim` which is the dimension of the system.

# %%
dim = 3
rdim = 2

m_kT = 0.5

m_gamma = 1
m_rgamma = 1/m_gamma
m_sigma = np.sqrt(2 * m_kT / m_gamma)
m_rsigma = (1/m_sigma)
m_rsigma_sqrd = m_rsigma**2
m_nu_s = 1

m_gamma_R = 1
m_rgamma_R = 1/m_gamma_R
m_sigma_R = np.sqrt(2 * m_kT / m_gamma_R)
m_rsigma_R = (1/m_sigma_R)
m_rsigma_R_sqrd = m_rsigma_R**2

m_As = np.array([-200, -100, -170, 15])
m_a = np.array([-1, -1, -6.5, .7])
m_b = np.array([0, 0, 11, .6])
m_c = np.array([-10, -10, -6.5, .7])
m_Ms = np.array([[[-1, 0], [0, -10]],
    [[-1, 0], [0, -10]],
    [[-6.5, 11./2], [11./2, -6.5]],
    [[0.7, 0.6/2], [0.6/2, 0.7]]])
m_ss = np.array([[1, 0], [0, 0.5], [-0.5, 1.5], [-1, 1]])

# %% [markdown]
# ### Dynamics
#
# `system_a` is the drift term of the system. It's used for plotting stream-plots, as well as finding fixed points of the deterministic system.
#
# `lagrangian` is the Lagrangian of the system. The Lagrangian used is the Geometric Action lagrangian (Heymann and Vanden-Eijnden), defined as
#
# $$
# L(x, \dot x) = |\dot x|_D |a(x)|_D - \langle \dot x , a(x) \rangle_D
# $$
#
# for any general Ito diffusion of the form
#
# $$
# dX = a(X)dt + \sqrt{\epsilon} dW.
# $$
#
# where $D=\sigma \sigma^T$ and the inner product is defined as $\langle a, b \rangle_D = \langle a, D^{-1} b \rangle$.The function also computes the partial derivatives of the Lagrangian, which are used for gradient optimisation. This can be enabled/disabled by setting the *args* argument to True/False. The partial derivatives of the geometric lagrangian are
#
# $$\begin{aligned}
# \frac{\partial L}{\partial x} & =  \nabla a( x ) \cdot \left( |\dot x|_D \hat{a}(x) - \dot x \right) \\
# \frac{\partial L}{\partial \dot x} & = |a(x)|_D \hat{\dot{x}} - a(x)
# \end{aligned}$$
#
# An important property of the geometric action is that it is time-reparameterisation invariant, meaning that $x$ can be replaced by any other path that shares the same *graph*.

# %% [markdown]
# #### Notes on the Muller-Brown system
#
# In this section some useful derivatives are computed, used for the gradient of the geometric action. Some relevant derivatives are
#
# $$
# \begin{aligned}
# \frac{\partial u^{(k)}}{\partial x_i} & = 2 u^{(k)}(\mathbf{x}) \left[ M^{(k)}_{ij}(\mathbf{x}_j - \mathbf{r}_j^{(k)})\right] \\
# \frac{ \partial^2 u^{(k)} }{\partial x_i \partial x_j} & = 2 u^{(k)}(\mathbf{x}) \left[ 2 M_{il}^{(k)} (x_l - r_l^{(k)}) M_{jn}^{(k)} (x_n - r_n^{(k)}) + M_{ji}^{(k)} \right] \\
# \frac{ \partial^2 U}{\partial x_i \partial x_j} & = \sum_{k=1}^4 2 u^{(k)}(\mathbf{x}) \left[ 2 M_{il}^{(k)} (x_l - r_l^{(k)}) M_{jn}^{(k)} (x_n - r_n^{(k)}) + M_{ji}^{(k)} \right]
# \end{aligned}
# $$
#
# We have $U(\mathbf{x}) = \sum_{i=1}^4 u^{(i)}$ and $F = - \nabla_r U$, so
#
# $$\begin{aligned}
#     \nabla_r F & = -\sum_{k=1}^4 2 u^{(k)}(\mathbf{x}) \left[ 2 (M^{(k)} (x - r^{(k)}))\ (M^{(n)} (x - r^{(k)}))^T + M^{(k)} \right].
# \end{aligned}$$
#
# The drift of the entire system (position and rotation) is $a = \left( \frac{1}{\gamma} \mathbf{F} + \frac{1}{\gamma} \nu_s \mathbf{p}, 0 \right)$. The second term in the positional component has the derivative
#
# $$
# \partial_\theta p = (-\sin \theta, \cos \theta).
# $$
#
# Letting $\nabla = (\partial_1, \partial_2, \partial_\theta)$, we can write the derivative of the drift term as
#
# $$
# \nabla a = \begin{pmatrix}
# \partial_1 F_1 & \partial_1 F_2 & 0 \\
# \partial_2 F_1 & \partial_2 F_2 & 0 \\
# -\sin \theta & \cos \theta & 0
# \end{pmatrix}
# $$

# %%
def system_a(x, y):
    xs = np.array([x,y])
    rs = np.zeros((2, 4))
    us = np.zeros(4)
    a_s = np.zeros(2)
    
    for i in range(4):
        rs[:, i] = m_Ms[i, :, :].dot( xs[:] - m_ss[i, :] )
        us[i] = m_As[i]*np.exp( (xs[:] - m_ss[i, :]).dot(rs[:, i]) )

        a_s[:] += -2*us[i]*rs[:, i]
        
    return a_s

def system_pot(x,y):
    pot=np.zeros(x.shape)
    _a = m_Ms[:, 0, 0]
    _b = m_Ms[:, 0, 1]*2
    _c = m_Ms[:, 1, 1]
    
    for i in range(4):
        dd = _a[i]*(x-m_ss[i][0])**2 + _b[i]*(x-m_ss[i][0])*(y-m_ss[i][1]) + _c[i]*(y-m_ss[i][1])**2
        pot += m_As[i]*np.exp(dd) 
        
    return pot

def lagrangian(ls, dxls, dvls, fvals, ts, args):
    compute_gradient = args
    
    xs, dxs = fvals
    
    rxs = xs[:, :2]
    drxs = dxs[:, :2]
    thetas = xs[:, 2]
    dthetas = dxs[:, 2]
    
    rs = np.zeros((rdim, 4, len(ts)))
    us = np.zeros((4, len(ts)))
    a_s = np.zeros((dim, len(ts)))
    
    _a = m_Ms[:, 0, 0]
    _b = m_Ms[:, 0, 1]*2
    _c = m_Ms[:, 1, 1]

    for i in range(4):
        us[i, :] = m_As[i]*np.exp(
            _a[i]*(rxs[:, 0]-m_ss[i][0])**2 + _b[i]*(rxs[:, 0]-m_ss[i][0])*(rxs[:, 1]-m_ss[i][1]) +
            _c[i]*(rxs[:, 1]-m_ss[i][1])**2)
        rs[0, i, :] = _a[i]*(rxs[:, 0]-m_ss[i][0])+0.5*_b[i]*(rxs[:, 1]-m_ss[i][1])
        rs[1, i, :] = _c[i]*(rxs[:, 1]-m_ss[i][1])+0.5*_b[i]*(rxs[:, 0]-m_ss[i][0])
        a_s[0, :] += -2*us[i, :]*rs[0, i, :]
        a_s[1, :] += -2*us[i, :]*rs[1, i, :]

    a_s[0, :] += m_nu_s*np.cos(thetas)
    a_s[1, :] += m_nu_s*np.sin(thetas)
    
    a_s[:, :] *= m_rgamma
    
    dxs_norm = m_rsigma*np.linalg.norm(dxs, axis=1)
    a_norm = m_rsigma*np.linalg.norm(a_s, axis=0)
    dxs_dot_a = m_rsigma_sqrd*(a_s[0,:].T*drxs[:,0] + a_s[1,:].T*drxs[:, 1] + 0)
    
    ls[:] = dxs_norm * a_norm - dxs_dot_a
    
    # Compute gradient
    
    if compute_gradient:

        ## Compute dL/dx

        da = np.zeros( (dim, dim, len(ts)) )

        for j in range(len(ts)):
            for i in range(4):
                da[:2, :2, j] += - 2 * us[i, j] * (2*np.outer(rs[:, i, j], rs[:, i, j]) + m_Ms[i]) 

        da[:2, :2, :] *= m_rgamma
                
        da[2, 0, :] = -m_nu_s*np.sin(thetas)
        da[2, 1, :] = m_nu_s*np.cos(thetas)
                
        a_normalized = a_s/a_norm

        a_normalized[:, np.where(a_norm==0)] = 0 # Set zero-norm vectors to 0

        for i in range(dxls.shape[0]):
            dxls[i, :] = da[:,:,i].dot( dxs_norm[i]*a_normalized[:,i] - dxs[i,:])

        ## Compute dL/dv

        dxs_2 = (dxs.T*(a_norm/dxs_norm)).T
        dxs_2[ np.where(dxs_norm==0),:] = 0

        dvls[:] = dxs_2 - a_s.T

# %% [markdown]
# ### Find fixed points of the system

# %%
from scipy.optimize import root

e_xa  = root(lambda x : system_a(x[0], x[1]), np.array([-0.5, 1.5])).x
e_xb  = root(lambda x : system_a(x[0], x[1]), np.array([0, 0.4])).x
e_xc  = root(lambda x : system_a(x[0], x[1]), np.array([0.5, 0])).x
e_xs1  = root(lambda x : system_a(x[0], x[1]), np.array([-0.7, 0.5])).x
e_xs2 = root(lambda x : system_a(x[0], x[1]), np.array([0.2, 0.4])).x

print(e_xa, e_xb, e_xc, e_xs1, e_xs2)
# Out:
# [-0.55822363  1.44172584] [-0.05001082  0.4666941 ] [0.6234994  0.02803776] [-0.82200156  0.6243128 ] [0.21248658 0.29298833]

# %% [markdown]
# ## Fixed manifolds

# %% [markdown]
# $\nu_s=40$

# %%
mc1 = np.array([-0.565538,-0.565547,-0.565572,-0.565613,-0.56567,-0.565743,-0.565831,-0.565933,-0.566048,-0.566175,-0.566314,-0.566463,-0.566622,-0.566788,-0.566961,-0.56714,-0.567325,-0.567513,-0.567704,-0.567899,-0.568096,-0.568295,-0.568498,-0.568703,-0.568913,-0.569128,-0.569351,-0.569591,-0.569855,-0.570132,-0.570422,-0.570727,-0.571046,-0.571385,-0.571745,-0.57212,-0.572508,-0.572907,-0.573308,-0.573701,-0.574104,-0.574518,-0.574948,-0.575429,-0.575937,-0.576447,-0.576947,-0.57734,-0.577667,-0.578027,-0.578468,-0.579255,-0.580191,-0.581142,-0.581962,-0.582467,-0.582854,-0.583153,-0.583347,-0.58354,-0.583813,-0.584406,-0.585221,-0.586114,-0.586981,-0.587772,-0.588457,-0.588885,-0.589124,-0.58927,-0.589305,-0.589418,-0.589824,-0.590914,-0.59216,-0.593205,-0.593937,-0.594573,-0.595144,-0.595767,-0.596676,-0.597939,-0.599103,-0.599621,-0.599826,-0.599892,-0.59993,-0.600052,-0.60047,-0.600837,-0.600778,-0.600525,-0.600353,-0.600295,-0.60026,-0.600203,-0.599931,-0.599189,-0.59837,-0.59785,-0.597424,-0.597004,-0.59652,-0.595773,-0.594939,-0.594438,-0.59421,-0.593905,-0.593455,-0.592979,-0.592433,-0.591538,-0.590374,-0.589708,-0.589515,-0.588555,-0.586795,-0.585627,-0.585224,-0.584859,-0.584265,-0.583051,-0.581515,-0.580694,-0.580345,-0.579701,-0.578752,-0.577411,-0.576113,-0.57564,-0.575251,-0.574188,-0.573071,-0.572234,-0.571475,-0.570718,-0.5697,-0.568415,-0.56738,-0.56663,-0.565938,-0.565143,-0.56388,-0.562534,-0.561685,-0.560986,-0.560257,-0.559272,-0.557903,-0.556752,-0.555966,-0.555216,-0.554371,-0.553207,-0.551933,-0.550982,-0.550148,-0.54924,-0.548276,-0.54723,-0.545952,-0.544442,-0.543372,-0.54282,-0.542228,-0.541376,-0.539872,-0.538178,-0.537198,-0.536622,-0.536299,-0.535604,-0.533688,-0.531829,-0.530829,-0.530345,-0.530305,-0.5304,-0.530358,-0.529575,-0.527972,-0.526595,-0.525583,-0.524019,-0.522013,-0.520652,-0.520059,-0.519841,-0.51974,-0.519165,-0.518298,-0.518235,-0.518958,-0.519424,-0.519507,-0.519985,-0.520997,-0.521906,-0.522462,-0.523051,-0.523863,-0.52455,-0.52482,-0.524921,-0.524844,-0.524908,-0.525622,-0.526761,-0.527904,-0.528874,-0.529612,-0.529956,-0.530298,-0.53105,-0.531961,-0.532838,-0.53362,-0.534326,-0.53487,-0.535464,-0.536404,-0.537519,-0.538447,-0.538772,-0.539008,-0.539483,-0.540213,-0.540976,-0.541605,-0.542176,-0.542714,-0.543211,-0.543736,-0.54437,-0.545166,-0.545959,-0.546636,-0.547139,-0.547584,-0.547994,-0.548394,-0.548832,-0.549355,-0.550079,-0.550844,-0.551608,-0.552311,-0.552945,-0.553495,-0.553908,-0.554079,-0.554224,-0.554402,-0.554776,-0.555398,-0.556058,-0.556708,-0.557259,-0.557623,-0.557937,-0.558217,-0.558476,-0.558732,-0.558992,-0.559262,-0.559547,-0.559854,-0.560248,-0.560691,-0.561134,-0.561566,-0.561977,-0.56236,-0.56266,-0.562898,-0.563111,-0.563305,-0.563483,-0.563648,-0.563802,-0.563948,-0.564088,-0.564221,-0.56435,-0.564474,-0.564594,-0.564708,-0.564818,-0.564923,-0.565021,-0.565113,-0.565198,-0.565274,-0.565342,-0.565401,-0.56545,-0.565488,-0.565516,-0.565533,-0.565538,1.42679,1.42678,1.42675,1.42671,1.42666,1.42659,1.42651,1.42641,1.4263,1.42618,1.42605,1.42591,1.42576,1.4256,1.42544,1.42527,1.42509,1.42492,1.42474,1.42455,1.42437,1.42418,1.42399,1.4238,1.4236,1.4234,1.42319,1.42297,1.42273,1.42247,1.4222,1.42192,1.42163,1.42131,1.42098,1.42063,1.42028,1.41991,1.41954,1.41918,1.41881,1.41844,1.41805,1.41761,1.41715,1.41669,1.41625,1.41584,1.41548,1.41515,1.41484,1.41467,1.4145,1.41425,1.41376,1.4128,1.41178,1.41082,1.41045,1.41028,1.41013,1.40965,1.40894,1.40817,1.40742,1.40673,1.40615,1.40583,1.40568,1.40561,1.40559,1.40553,1.40529,1.40464,1.40391,1.4033,1.40288,1.40253,1.4022,1.40186,1.40135,1.40066,1.40005,1.39986,1.39985,1.39981,1.3997,1.39953,1.39928,1.39912,1.39938,1.39981,1.40009,1.4002,1.40026,1.40036,1.40084,1.40216,1.4036,1.4045,1.40522,1.40594,1.40676,1.408,1.40937,1.41019,1.41056,1.41106,1.41178,1.41244,1.41307,1.41409,1.41543,1.41628,1.41655,1.41691,1.41761,1.41893,1.42069,1.42191,1.42253,1.42302,1.42364,1.42485,1.4264,1.42761,1.42849,1.42901,1.42956,1.43078,1.4322,1.43341,1.43449,1.43538,1.43618,1.43697,1.43802,1.43935,1.44041,1.44118,1.44189,1.44269,1.44397,1.44532,1.44617,1.44687,1.44759,1.44856,1.4499,1.45102,1.45179,1.45251,1.45332,1.45443,1.45565,1.45655,1.45734,1.45819,1.45911,1.46017,1.46092,1.46128,1.46218,1.46369,1.46483,1.46552,1.4659,1.46639,1.4679,1.46958,1.47018,1.47043,1.47075,1.47164,1.47365,1.47513,1.4752,1.47502,1.47508,1.47557,1.47653,1.47734,1.47792,1.47881,1.47992,1.48052,1.48062,1.48075,1.48102,1.48149,1.48192,1.48163,1.48065,1.47985,1.47928,1.47812,1.47626,1.47464,1.47364,1.47261,1.47122,1.47008,1.46972,1.46964,1.46974,1.46966,1.46883,1.46749,1.46616,1.46505,1.4642,1.4638,1.46341,1.46256,1.46152,1.46053,1.45966,1.45886,1.45815,1.45753,1.45709,1.4567,1.45615,1.45516,1.45407,1.45311,1.4523,1.45157,1.4509,1.45029,1.44972,1.44919,1.44864,1.44797,1.44713,1.4463,1.44558,1.44506,1.4446,1.44417,1.44376,1.44331,1.44276,1.44196,1.44116,1.44044,1.44008,1.4399,1.43974,1.43949,1.43901,1.43847,1.43787,1.43723,1.43656,1.43592,1.43531,1.4348,1.43444,1.43413,1.43385,1.4336,1.43335,1.43309,1.43283,1.43255,1.43225,1.43187,1.43144,1.43101,1.43059,1.43019,1.42982,1.42953,1.4293,1.4291,1.42891,1.42874,1.42858,1.42843,1.42829,1.42816,1.42803,1.42791,1.42779,1.42768,1.42757,1.42747,1.42737,1.42728,1.42719,1.42711,1.42704,1.42697,1.42692,1.42687,1.42683,1.42681,1.42679,1.42679])
contour_ff1 = pyritz.funcs.CollocationFF(int(len(mc1)/2), 2, derivatives=0)

ts = np.linspace(-1,1,1000)
pts = contour_ff1.evaluate(mc1, ts)
plt.plot(pts[:,0], pts[:,1])

single_pt = contour_ff1.evaluate(mc1, -0.6)
plt.plot(single_pt[0], single_pt[1], "X")

# %%
mc2 = np.array([-0.814888,-0.814878,-0.814848,-0.814798,-0.814727,-0.814637,-0.814526,-0.814396,-0.814247,-0.814078,-0.813891,-0.813685,-0.813463,-0.813226,-0.812974,-0.81271,-0.812437,-0.812156,-0.811872,-0.811589,-0.811311,-0.811045,-0.810795,-0.810635,-0.810529,-0.810433,-0.810325,-0.810183,-0.809877,-0.809436,-0.808936,-0.808397,-0.807872,-0.807403,-0.806939,-0.806478,-0.806005,-0.805529,-0.805065,-0.804634,-0.804274,-0.803929,-0.803579,-0.803156,-0.802707,-0.802238,-0.801744,-0.801259,-0.800816,-0.800455,-0.800122,-0.799796,-0.799455,-0.799073,-0.798581,-0.798072,-0.797637,-0.797253,-0.796859,-0.796419,-0.795922,-0.795302,-0.794703,-0.79432,-0.793992,-0.793498,-0.792978,-0.792727,-0.792586,-0.792211,-0.791639,-0.790948,-0.790277,-0.789879,-0.78966,-0.789535,-0.789418,-0.789222,-0.788789,-0.788076,-0.787587,-0.787322,-0.78682,-0.786257,-0.7859,-0.785577,-0.785261,-0.785119,-0.785064,-0.784941,-0.784706,-0.784384,-0.784193,-0.78401,-0.783742,-0.783551,-0.783337,-0.782933,-0.782658,-0.782491,-0.782237,-0.782109,-0.782079,-0.781981,-0.781955,-0.781981,-0.781981,-0.78202,-0.782092,-0.782175,-0.782246,-0.782366,-0.782571,-0.782822,-0.783193,-0.783511,-0.783517,-0.784115,-0.784714,-0.784946,-0.785468,-0.786218,-0.78723,-0.788422,-0.789213,-0.789755,-0.790302,-0.791238,-0.793489,-0.795485,-0.796989,-0.798864,-0.800398,-0.802125,-0.803854,-0.804985,-0.80636,-0.807482,-0.808142,-0.808588,-0.809841,-0.811214,-0.812127,-0.812517,-0.813377,-0.814444,-0.815733,-0.817063,-0.817988,-0.819878,-0.821117,-0.821252,-0.821404,-0.821763,-0.822911,-0.824528,-0.825865,-0.826642,-0.827673,-0.829002,-0.83043,-0.831929,-0.833429,-0.834458,-0.834822,-0.83494,-0.836376,-0.838137,-0.839424,-0.840372,-0.841571,-0.842784,-0.843909,-0.845129,-0.846216,-0.847255,-0.848302,-0.849298,-0.850313,-0.851489,-0.852673,-0.852952,-0.853006,-0.853387,-0.854363,-0.854693,-0.855246,-0.856204,-0.856478,-0.856767,-0.857273,-0.857979,-0.858385,-0.858868,-0.859695,-0.860289,-0.860613,-0.860788,-0.861302,-0.861702,-0.86186,-0.862186,-0.862439,-0.862523,-0.862562,-0.862585,-0.862564,-0.862191,-0.861787,-0.861761,-0.861775,-0.861746,-0.861731,-0.861452,-0.860801,-0.860348,-0.860041,-0.859551,-0.858799,-0.857741,-0.857152,-0.857145,-0.857168,-0.857163,-0.857284,-0.857105,-0.856033,-0.85486,-0.854058,-0.85342,-0.852919,-0.852637,-0.852591,-0.852648,-0.852697,-0.852283,-0.851095,-0.849833,-0.848969,-0.84826,-0.847778,-0.847247,-0.846212,-0.844979,-0.844145,-0.843939,-0.843906,-0.843939,-0.843755,-0.842911,-0.841335,-0.839668,-0.838568,-0.837704,-0.836785,-0.835282,-0.833747,-0.832362,-0.831563,-0.830945,-0.830427,-0.829959,-0.829449,-0.828831,-0.827896,-0.826627,-0.825341,-0.824131,-0.823302,-0.822726,-0.82222,-0.821735,-0.821142,-0.820383,-0.819641,-0.818942,-0.818307,-0.817802,-0.817474,-0.817204,-0.816977,-0.816781,-0.816608,-0.81645,-0.816302,-0.816161,-0.816025,-0.815891,-0.815761,-0.815634,-0.815512,-0.815395,-0.815287,-0.815188,-0.815101,-0.815026,-0.814967,-0.814924,-0.814897,-0.814888,0.584821,0.584825,0.584835,0.584853,0.584878,0.58491,0.58495,0.584998,0.585054,0.585118,0.58519,0.585271,0.585361,0.585459,0.585565,0.585678,0.585798,0.585924,0.586053,0.586184,0.586316,0.586444,0.586565,0.586639,0.586684,0.586728,0.586782,0.58686,0.587034,0.587288,0.58758,0.587902,0.588226,0.588528,0.588837,0.58915,0.589472,0.5898,0.590126,0.590443,0.590728,0.591014,0.591313,0.591658,0.592033,0.592441,0.592917,0.593399,0.593838,0.594181,0.594503,0.594843,0.595223,0.595659,0.596213,0.596801,0.597345,0.597859,0.598381,0.598938,0.599597,0.600503,0.601409,0.602008,0.602547,0.603375,0.604253,0.604666,0.604916,0.605658,0.606815,0.608237,0.609641,0.61053,0.611063,0.611355,0.611648,0.612171,0.613323,0.615222,0.616584,0.617421,0.618927,0.620636,0.621847,0.623024,0.624205,0.624774,0.625024,0.625475,0.626448,0.627873,0.628804,0.629828,0.631385,0.632761,0.634177,0.63608,0.637961,0.639857,0.642085,0.643219,0.643856,0.645887,0.647052,0.647357,0.647788,0.649426,0.651184,0.651712,0.652304,0.653374,0.654871,0.655814,0.65719,0.658495,0.658507,0.659716,0.660999,0.661489,0.662178,0.663167,0.664253,0.665115,0.665698,0.666033,0.666202,0.666379,0.667087,0.667587,0.667663,0.667598,0.667308,0.667089,0.666961,0.666734,0.666432,0.666146,0.665938,0.665774,0.665352,0.664889,0.664572,0.664424,0.664121,0.663684,0.6631,0.66248,0.662069,0.661165,0.660564,0.660494,0.660413,0.660236,0.659603,0.658669,0.657859,0.657408,0.656781,0.655934,0.654997,0.654013,0.652973,0.652232,0.651961,0.651876,0.650763,0.649353,0.648276,0.647484,0.646439,0.645331,0.64426,0.643101,0.642024,0.64093,0.639784,0.638696,0.637535,0.636097,0.634586,0.634239,0.634177,0.633652,0.632299,0.631846,0.63097,0.629439,0.628992,0.628464,0.62754,0.626277,0.625529,0.62448,0.622599,0.621169,0.620348,0.619812,0.618059,0.616758,0.616157,0.613816,0.612024,0.611639,0.611249,0.610101,0.60782,0.604945,0.602746,0.602557,0.602641,0.602551,0.6025,0.60172,0.599923,0.598809,0.598258,0.597288,0.596018,0.594519,0.59371,0.593702,0.593735,0.59373,0.59386,0.593667,0.592493,0.591272,0.59057,0.590049,0.589625,0.589385,0.589345,0.589386,0.589418,0.589136,0.588325,0.5875,0.587024,0.586666,0.586389,0.586105,0.585639,0.585111,0.584759,0.584673,0.584666,0.584668,0.584611,0.584362,0.583901,0.583435,0.583168,0.583011,0.582886,0.582699,0.582524,0.582378,0.5823,0.582256,0.582238,0.582231,0.582244,0.582277,0.58234,0.582432,0.582533,0.582637,0.582712,0.582776,0.582849,0.582936,0.583063,0.58324,0.583421,0.583596,0.58376,0.583891,0.583974,0.584044,0.584105,0.584161,0.584212,0.584262,0.58431,0.584358,0.584405,0.584453,0.5845,0.584547,0.584592,0.584634,0.584674,0.584711,0.584743,0.584771,0.584792,0.584808,0.584818,0.584821])
contour_ff2 = pyritz.funcs.CollocationFF(int(len(mc2)/2), 2, derivatives=0)

ts = np.linspace(-1,1,1000)
pts = contour_ff2.evaluate(mc2, ts)
plt.plot(pts[:,0], pts[:,1])
single_pt = contour_ff2.evaluate(mc2, -0.9)
plt.plot(single_pt[0], single_pt[1], "X")

# %%
mc3 = np.array([-0.0280699,-0.0281098,-0.0282282,-0.0284213,-0.028683,-0.029005,-0.0293775,-0.0297894,-0.0302289,-0.0306847,-0.0311461,-0.0316044,-0.0320539,-0.0324928,-0.0329247,-0.0333598,-0.0338162,-0.0343218,-0.03495,-0.035909,-0.036988,-0.0381557,-0.0393597,-0.040491,-0.0415802,-0.042589,-0.0432174,-0.0437224,-0.0444337,-0.0462413,-0.0486276,-0.0508617,-0.0513238,-0.0515432,-0.0527463,-0.0551277,-0.0573331,-0.0581981,-0.0588742,-0.0603887,-0.0619677,-0.0627946,-0.0632557,-0.0637717,-0.0644769,-0.0656931,-0.0670776,-0.0682657,-0.0702794,-0.0732684,-0.0747505,-0.0749941,-0.0756008,-0.0774511,-0.0806363,-0.0822419,-0.0836638,-0.0861814,-0.0869452,-0.0879379,-0.0907376,-0.0923747,-0.0936638,-0.09534,-0.0977609,-0.0987664,-0.0989419,-0.0990853,-0.0994694,-0.102861,-0.105663,-0.1089,-0.113954,-0.115672,-0.116809,-0.119683,-0.122252,-0.124084,-0.126043,-0.126845,-0.128637,-0.130937,-0.13186,-0.132879,-0.135661,-0.138309,-0.140467,-0.144136,-0.147089,-0.147054,-0.147793,-0.149928,-0.15149,-0.151554,-0.152662,-0.155606,-0.155811,-0.156479,-0.158061,-0.159145,-0.159278,-0.159261,-0.159875,-0.160846,-0.161226,-0.161376,-0.1613,-0.160976,-0.159756,-0.159466,-0.159325,-0.157331,-0.156255,-0.155261,-0.153906,-0.15191,-0.149204,-0.147415,-0.14696,-0.145568,-0.142651,-0.140059,-0.138206,-0.137259,-0.135639,-0.133935,-0.132229,-0.13105,-0.129171,-0.12733,-0.127,-0.123423,-0.122967,-0.120456,-0.119321,-0.116507,-0.11183,-0.110633,-0.106141,-0.101337,-0.096852,-0.0918661,-0.0859703,-0.0794835,-0.0717883,-0.0667759,-0.0632618,-0.0594826,-0.058921,-0.0561036,-0.0515567,-0.0484756,-0.0462653,-0.0422538,-0.0387521,-0.0356926,-0.0338731,-0.0308728,-0.0287234,-0.0271017,-0.0263459,-0.0235254,-0.0213638,-0.0195978,-0.0182635,-0.016141,-0.0149432,-0.0136372,-0.0106879,-0.00902198,-0.00662214,-0.00522858,-0.00309146,5.46576e-6,0.00169847,0.00293699,0.00596402,0.00820478,0.0101459,0.0119642,0.0132477,0.0169357,0.0181244,0.0223258,0.0255727,0.0286309,0.0299218,0.0315343,0.0332771,0.0353419,0.0365881,0.0378677,0.0403744,0.0410152,0.0420382,0.0432155,0.0439255,0.0446418,0.0452408,0.0463506,0.0476344,0.048478,0.04932,0.0502385,0.0509532,0.0518586,0.053286,0.0537775,0.0539596,0.0548033,0.0556464,0.0561618,0.0569281,0.0573706,0.0573734,0.0574485,0.0577749,0.0581035,0.0579462,0.0579742,0.0579254,0.0576753,0.0571252,0.0567308,0.0561296,0.0548946,0.0535097,0.0529633,0.0514144,0.0502037,0.048648,0.0465499,0.0456129,0.0453015,0.0438745,0.0411512,0.0383219,0.0375424,0.037594,0.03639,0.0316259,0.0295378,0.0295023,0.0291197,0.0253419,0.0215295,0.021282,0.0214346,0.0210952,0.0197239,0.0172902,0.0142381,0.0131355,0.0128151,0.00997465,0.0069175,0.00587967,0.00520385,0.00412946,0.0029059,0.00150718,0.000092066,-0.00117016,-0.00249382,-0.00427249,-0.00593083,-0.00669073,-0.00673676,-0.0069067,-0.00798274,-0.00946307,-0.0113849,-0.0137402,-0.01597,-0.01764,-0.0184194,-0.018974,-0.0194628,-0.0202598,-0.0211262,-0.0220012,-0.0228642,-0.0237557,-0.0245982,-0.0253599,-0.0260276,-0.0265947,-0.0270606,-0.0274291,-0.0277077,-0.0279065,-0.0280374,-0.0281131,-0.0281465,-0.0281503,-0.0281359,-0.0281135,-0.0280914,-0.0280756,-0.0280699,0.446849,0.446854,0.446869,0.446893,0.446926,0.446967,0.447014,0.447067,0.447125,0.447186,0.447248,0.447312,0.447376,0.447439,0.447503,0.447568,0.447636,0.447709,0.447793,0.447908,0.448036,0.448175,0.448323,0.44848,0.448637,0.448788,0.448894,0.448982,0.449091,0.449319,0.449607,0.449874,0.449927,0.44996,0.450146,0.450507,0.450838,0.450957,0.451046,0.451262,0.451491,0.451617,0.451692,0.451765,0.451867,0.452056,0.452279,0.45248,0.452797,0.453248,0.453479,0.453529,0.453618,0.453921,0.454467,0.454768,0.455012,0.45538,0.455487,0.455689,0.456237,0.456506,0.456703,0.456988,0.457413,0.457598,0.457635,0.457659,0.457728,0.458386,0.458974,0.459634,0.46059,0.460953,0.461156,0.46179,0.462359,0.462744,0.463177,0.463382,0.463803,0.464404,0.464611,0.464833,0.465572,0.466377,0.466978,0.467971,0.468874,0.468881,0.469141,0.469904,0.47047,0.470483,0.470947,0.472261,0.472334,0.472672,0.473588,0.474298,0.474394,0.474388,0.474992,0.475981,0.476795,0.477182,0.477813,0.478633,0.479763,0.480005,0.480071,0.481056,0.481418,0.481769,0.48213,0.482592,0.483112,0.483465,0.483566,0.483774,0.484133,0.484416,0.484613,0.48473,0.484822,0.484986,0.485094,0.485162,0.485287,0.485375,0.4854,0.485552,0.485566,0.485646,0.485686,0.485618,0.485766,0.485773,0.485652,0.485623,0.485467,0.485359,0.485175,0.484801,0.484406,0.48407,0.483807,0.483487,0.483427,0.483173,0.48267,0.482397,0.482167,0.481623,0.48128,0.48089,0.480635,0.48025,0.479952,0.479702,0.479596,0.479155,0.478835,0.478555,0.47833,0.47797,0.477756,0.477532,0.476991,0.476676,0.47626,0.475959,0.475473,0.474885,0.474534,0.47427,0.473558,0.473035,0.472604,0.472121,0.471801,0.470857,0.470516,0.46927,0.468318,0.467346,0.466959,0.46635,0.465748,0.465021,0.464535,0.464011,0.463014,0.462719,0.46226,0.46175,0.461428,0.46108,0.460759,0.460204,0.459548,0.459078,0.458561,0.458028,0.457605,0.457005,0.455981,0.455631,0.455491,0.454747,0.453959,0.453407,0.452457,0.45188,0.451854,0.451657,0.450938,0.449551,0.448208,0.44812,0.447989,0.447652,0.446861,0.446387,0.445953,0.445218,0.44462,0.444402,0.443937,0.443633,0.443374,0.443034,0.44285,0.44278,0.442654,0.442442,0.442238,0.442215,0.442232,0.442207,0.442123,0.442116,0.442145,0.44215,0.442233,0.442324,0.442344,0.442345,0.442361,0.442431,0.442567,0.442743,0.442792,0.442803,0.443032,0.443279,0.443346,0.443384,0.443461,0.443563,0.443699,0.443846,0.443989,0.444129,0.444273,0.444394,0.444443,0.444442,0.444469,0.444609,0.444792,0.445006,0.44524,0.445459,0.445631,0.445731,0.445811,0.445882,0.445967,0.446056,0.446146,0.446237,0.446344,0.446448,0.446544,0.446629,0.4467,0.446758,0.446803,0.446836,0.446858,0.44687,0.446876,0.446875,0.446872,0.446866,0.44686,0.446854,0.446851,0.446849])
contour_ff3 = pyritz.funcs.CollocationFF(int(len(mc3)/2), 2, derivatives=0)

ts = np.linspace(-1,1,1000)
pts = contour_ff3.evaluate(mc3, ts)
plt.plot(pts[:,0], pts[:,1])

single_pt = contour_ff3.evaluate(mc3, 0.8)
plt.plot(single_pt[0], single_pt[1], "X")

# %%
mc4 = np.array([0.233037,0.233014,0.232946,0.232839,0.232701,0.232545,0.232384,0.232236,0.232119,0.232052,0.232055,0.232144,0.232336,0.232644,0.233075,0.233631,0.234307,0.235089,0.23595,0.236852,0.237664,0.238207,0.238678,0.23908,0.239423,0.239724,0.239995,0.240254,0.240536,0.240978,0.241433,0.241861,0.242113,0.242259,0.242381,0.242582,0.242848,0.243158,0.243525,0.243925,0.244326,0.244711,0.245115,0.245633,0.24612,0.246384,0.246437,0.246409,0.246391,0.246588,0.24716,0.247805,0.248343,0.248712,0.248825,0.248874,0.248968,0.249245,0.249664,0.249843,0.249952,0.250488,0.250941,0.251007,0.251006,0.251079,0.251437,0.251777,0.251942,0.251962,0.252107,0.252556,0.25277,0.252883,0.253088,0.253219,0.253373,0.253596,0.253743,0.254012,0.254286,0.2543,0.254501,0.254685,0.25481,0.255081,0.255252,0.255306,0.255303,0.255298,0.255216,0.254979,0.254805,0.254728,0.254557,0.254441,0.2542,0.253972,0.253597,0.253152,0.253157,0.253148,0.253171,0.252677,0.252153,0.251986,0.251864,0.251496,0.251237,0.250925,0.250684,0.250591,0.24953,0.248717,0.248778,0.248007,0.246542,0.24659,0.24622,0.244209,0.243349,0.242052,0.241831,0.241911,0.238535,0.23676,0.235774,0.233935,0.231812,0.230559,0.229483,0.227807,0.225963,0.224579,0.22357,0.221403,0.219334,0.217423,0.213457,0.211241,0.210561,0.208982,0.205862,0.204033,0.203772,0.201626,0.199968,0.198901,0.197279,0.195772,0.194374,0.192898,0.191286,0.190166,0.188549,0.186369,0.186099,0.18606,0.184279,0.182723,0.181884,0.180411,0.179558,0.179263,0.178865,0.177003,0.175395,0.174146,0.172588,0.171527,0.170879,0.170378,0.170202,0.169828,0.169352,0.169221,0.168708,0.168255,0.168052,0.167991,0.167895,0.167655,0.167537,0.167422,0.167341,0.167345,0.167386,0.167461,0.167605,0.167839,0.168209,0.168656,0.16896,0.169423,0.170191,0.170953,0.171407,0.171956,0.172883,0.173078,0.174107,0.174534,0.174646,0.175827,0.177819,0.178428,0.179203,0.180773,0.182138,0.182957,0.183959,0.186008,0.187195,0.187843,0.188517,0.189272,0.189877,0.190236,0.190901,0.192546,0.192935,0.192838,0.192845,0.192773,0.194086,0.195963,0.196847,0.197145,0.197485,0.198442,0.200075,0.201461,0.201735,0.202031,0.20279,0.204504,0.205735,0.206159,0.206766,0.207564,0.20847,0.209379,0.210252,0.21134,0.212487,0.212912,0.213006,0.213766,0.214922,0.216128,0.217136,0.217409,0.217432,0.217998,0.219008,0.220097,0.22109,0.221803,0.221882,0.221929,0.222446,0.223286,0.22415,0.224796,0.225375,0.2259,0.226383,0.226837,0.227283,0.227741,0.228167,0.22855,0.228735,0.228926,0.22919,0.229636,0.230497,0.231371,0.23218,0.232868,0.233168,0.233252,0.233254,0.233203,0.233127,0.233041,0.232961,0.232894,0.232846,0.232818,0.23281,0.232819,0.232842,0.232875,0.232913,0.232952,0.232986,0.233014,0.233031,0.233037,0.330359,0.330369,0.330399,0.330447,0.330507,0.330577,0.330648,0.330713,0.330765,0.330795,0.330794,0.330755,0.33067,0.330534,0.330342,0.330095,0.329794,0.329445,0.329058,0.328651,0.32828,0.328022,0.327792,0.327587,0.327403,0.327234,0.327073,0.32691,0.326728,0.326454,0.326171,0.325903,0.325746,0.325653,0.32557,0.32543,0.325241,0.325015,0.324741,0.324438,0.324132,0.323835,0.323511,0.323067,0.322638,0.322406,0.322358,0.322386,0.322404,0.322215,0.321661,0.321014,0.320431,0.320022,0.319902,0.319852,0.319745,0.319412,0.318899,0.318684,0.318538,0.3178,0.317173,0.317085,0.31709,0.316976,0.316409,0.315869,0.315604,0.315576,0.315308,0.314481,0.314073,0.313828,0.313398,0.313121,0.312763,0.31221,0.311826,0.311063,0.310274,0.310221,0.30945,0.308709,0.308057,0.306545,0.30445,0.303454,0.303638,0.303511,0.301525,0.29957,0.298518,0.29803,0.297247,0.296779,0.295923,0.295159,0.294074,0.292838,0.292856,0.292834,0.292888,0.291771,0.290608,0.290253,0.290022,0.289334,0.288833,0.288287,0.287878,0.287707,0.286064,0.284819,0.284895,0.283882,0.281965,0.282042,0.281623,0.279316,0.278443,0.277155,0.276924,0.276977,0.274132,0.272619,0.271847,0.270556,0.269087,0.268231,0.267617,0.266651,0.265662,0.264976,0.264443,0.26344,0.262557,0.261882,0.260445,0.259732,0.259557,0.25908,0.25839,0.257951,0.257913,0.257609,0.257442,0.257326,0.257227,0.2572,0.257162,0.257201,0.257317,0.257388,0.257584,0.257955,0.258002,0.258012,0.25847,0.258939,0.259234,0.25985,0.260222,0.26033,0.26053,0.261623,0.262803,0.263801,0.265315,0.266563,0.267475,0.26823,0.268499,0.269208,0.270118,0.27044,0.271756,0.273189,0.273849,0.274113,0.274568,0.275816,0.276614,0.277945,0.27911,0.280077,0.281301,0.282842,0.284372,0.285837,0.287729,0.289731,0.290869,0.292363,0.294478,0.296487,0.297642,0.298853,0.300887,0.301257,0.303178,0.303977,0.304183,0.306081,0.309247,0.31015,0.311214,0.313243,0.314971,0.31595,0.317043,0.319151,0.320351,0.320973,0.321582,0.322232,0.322741,0.323045,0.323566,0.324815,0.32511,0.325035,0.325041,0.324995,0.325859,0.327075,0.327598,0.327774,0.32796,0.328461,0.329237,0.329877,0.33,0.33011,0.330383,0.330994,0.331422,0.331546,0.3317,0.331896,0.332118,0.332316,0.332467,0.332638,0.332813,0.332884,0.332891,0.33294,0.333011,0.333076,0.333124,0.333144,0.333138,0.33311,0.333066,0.333015,0.332963,0.332925,0.332925,0.332916,0.332851,0.332746,0.332629,0.332521,0.332413,0.332311,0.332217,0.332123,0.332023,0.33191,0.331801,0.331702,0.331664,0.33162,0.33155,0.33142,0.331154,0.330882,0.330628,0.330412,0.330318,0.330292,0.330292,0.330307,0.330331,0.330358,0.330383,0.330403,0.330418,0.330427,0.33043,0.330427,0.33042,0.330409,0.330398,0.330386,0.330375,0.330366,0.330361,0.330359])
contour_ff4 = pyritz.funcs.CollocationFF(int(len(mc4)/2), 2, derivatives=0)

ts = np.linspace(-1,1,1000)
pts = contour_ff4.evaluate(mc4, ts)
plt.plot(pts[:,0], pts[:,1])

single_pt = contour_ff4.evaluate(mc4, -0.22)
plt.plot(single_pt[0], single_pt[1], "X")

# %%
mc5 = np.array([0.580588,0.580584,0.580572,0.580551,0.580524,0.580488,0.580447,0.580398,0.580345,0.580286,0.580224,0.580157,0.580089,0.580018,0.579945,0.579872,0.579798,0.579723,0.579647,0.57957,0.579491,0.579409,0.579322,0.579228,0.579125,0.579009,0.578877,0.578724,0.578529,0.5782,0.577846,0.577479,0.577113,0.576766,0.576458,0.576326,0.57629,0.576322,0.57642,0.57658,0.576816,0.577122,0.577456,0.577796,0.578117,0.578298,0.578386,0.57843,0.578443,0.578451,0.578474,0.578491,0.578503,0.578482,0.578424,0.578418,0.578509,0.578907,0.579513,0.58016,0.580722,0.580878,0.581005,0.581199,0.581851,0.582715,0.583574,0.584111,0.584327,0.58445,0.584555,0.58473,0.585089,0.585926,0.587252,0.588692,0.589767,0.590598,0.591625,0.593635,0.596016,0.598174,0.599188,0.599779,0.600062,0.600223,0.600611,0.602024,0.603914,0.605702,0.606942,0.60783,0.608063,0.608032,0.608304,0.609266,0.610544,0.612151,0.61377,0.61496,0.615654,0.616126,0.616463,0.617013,0.618551,0.620282,0.621057,0.621173,0.62207,0.62428,0.626245,0.626738,0.626753,0.626794,0.626791,0.626543,0.626572,0.627935,0.630484,0.633298,0.635845,0.63746,0.63767,0.637455,0.637329,0.637901,0.640379,0.642823,0.642968,0.642974,0.644982,0.647305,0.648113,0.648215,0.6484,0.648866,0.650094,0.651651,0.652649,0.653315,0.654413,0.655683,0.656196,0.656247,0.657007,0.658351,0.659277,0.659765,0.660428,0.66131,0.662099,0.662747,0.663376,0.663988,0.664517,0.664891,0.664925,0.664587,0.664077,0.663502,0.662995,0.662599,0.662017,0.661135,0.660251,0.659501,0.658777,0.658047,0.657108,0.655748,0.654552,0.65412,0.653552,0.652115,0.65013,0.647259,0.644533,0.643304,0.642904,0.642684,0.642425,0.641849,0.640929,0.639725,0.638369,0.637351,0.636942,0.636422,0.635168,0.633855,0.633045,0.632375,0.631557,0.630559,0.629344,0.627946,0.626631,0.625623,0.624789,0.624175,0.623635,0.622964,0.622145,0.621354,0.620748,0.620099,0.619142,0.618061,0.617148,0.616596,0.616165,0.61584,0.615447,0.614718,0.613367,0.612022,0.611228,0.610901,0.610722,0.610582,0.610306,0.609625,0.608227,0.606801,0.605843,0.605523,0.605391,0.605311,0.605161,0.604836,0.603976,0.602704,0.601445,0.600607,0.600275,0.600095,0.599957,0.599754,0.599475,0.599069,0.598254,0.597325,0.596412,0.595706,0.595319,0.595015,0.594747,0.594407,0.594006,0.593593,0.59317,0.592743,0.592315,0.591888,0.591464,0.591053,0.590665,0.590275,0.589879,0.589473,0.588994,0.588466,0.587958,0.587485,0.587062,0.586737,0.586625,0.58655,0.586493,0.586438,0.58637,0.586279,0.586062,0.585806,0.585531,0.585242,0.584943,0.584639,0.584334,0.584029,0.583728,0.583434,0.583148,0.582872,0.582608,0.582358,0.582121,0.581899,0.581693,0.581504,0.581332,0.581177,0.581039,0.58092,0.580819,0.580736,0.580671,0.580625,0.580597,0.580588,0.0342857,0.0342838,0.0342783,0.0342691,0.0342564,0.0342404,0.0342214,0.0341996,0.0341753,0.0341489,0.0341206,0.0340907,0.0340595,0.0340273,0.033994,0.0339599,0.0339247,0.0338883,0.0338502,0.0338098,0.0337664,0.0337188,0.0336655,0.0336049,0.0335348,0.0334528,0.0333558,0.0332405,0.0330944,0.0328685,0.0326182,0.0323481,0.0320638,0.0317725,0.0314825,0.031275,0.0310949,0.0309185,0.0307378,0.0305432,0.030272,0.0299116,0.0295415,0.0291817,0.0288547,0.0286727,0.0285897,0.0285562,0.0285587,0.0285638,0.0285496,0.028542,0.028539,0.0285537,0.0285861,0.0285921,0.0285492,0.028348,0.0280399,0.0277107,0.027422,0.0273218,0.0272513,0.0271756,0.0269684,0.0267002,0.0264326,0.0262454,0.0261402,0.0260615,0.0259923,0.0259124,0.0257976,0.0255826,0.0252659,0.0249324,0.0246955,0.0245243,0.024311,0.0238575,0.0233189,0.0228454,0.022681,0.0226188,0.0225925,0.0225497,0.0224783,0.0222937,0.0220516,0.0218068,0.0216003,0.0214391,0.0213843,0.0213883,0.0213863,0.0213346,0.0212491,0.0210926,0.0209207,0.0208,0.020739,0.0206928,0.0206387,0.0205709,0.0204472,0.0203204,0.0202706,0.0202759,0.0202349,0.020108,0.0199949,0.0199714,0.0199753,0.019974,0.0199739,0.0199788,0.019978,0.019945,0.01989,0.0198575,0.0198596,0.0198662,0.0198648,0.019862,0.019857,0.0198702,0.019931,0.0199918,0.0199851,0.0199963,0.0201287,0.0202871,0.0203692,0.0204078,0.020417,0.020439,0.0205498,0.0207187,0.0208926,0.0210563,0.0212003,0.0213124,0.0213353,0.0213455,0.0215806,0.0219722,0.0221921,0.0222522,0.0224095,0.0226963,0.0229827,0.0232915,0.023829,0.0245632,0.025154,0.0255259,0.0258489,0.0262059,0.0267546,0.0275071,0.0280962,0.0283958,0.0286994,0.0291111,0.0294566,0.0296717,0.0299082,0.0302488,0.0306416,0.0310847,0.0314446,0.0315621,0.0316688,0.0319429,0.0323311,0.032938,0.0335199,0.0337648,0.0338296,0.0338778,0.0339394,0.0340452,0.0341941,0.0343632,0.0345352,0.0346687,0.0347394,0.0348178,0.0349685,0.0351135,0.0351775,0.0352202,0.0352997,0.0354098,0.0355267,0.0356432,0.0357622,0.0358866,0.0359956,0.0360635,0.0361047,0.0361268,0.0361405,0.036166,0.0362278,0.0362999,0.0363744,0.0364403,0.0364796,0.0364778,0.0364709,0.0364899,0.036526,0.0365727,0.0366292,0.0366773,0.0366902,0.0366776,0.0366628,0.0366738,0.0366926,0.0367153,0.0367392,0.0367577,0.0367594,0.0367428,0.0367244,0.0367203,0.0367297,0.0367388,0.0367377,0.0367256,0.0367079,0.0366837,0.0366549,0.0366283,0.0366118,0.0366147,0.036618,0.0366163,0.0365921,0.0365577,0.0365171,0.0364711,0.0364213,0.0363736,0.036331,0.0363063,0.0362943,0.036285,0.0362749,0.0362592,0.0362367,0.0362072,0.0361698,0.0361175,0.0360442,0.0359677,0.0358922,0.0358213,0.0357673,0.0357288,0.0356966,0.0356695,0.0356465,0.0356288,0.0356216,0.0356136,0.0356026,0.0355868,0.0355649,0.0355359,0.035483,0.0354217,0.0353562,0.0352878,0.0352178,0.0351471,0.0350766,0.0350072,0.0349394,0.0348739,0.0348109,0.0347509,0.0346942,0.034641,0.0345913,0.0345454,0.0345033,0.0344649,0.0344304,0.0343997,0.0343727,0.0343494,0.0343298,0.0343139,0.0343015,0.0342927,0.0342875,0.0342857])
contour_ff5 = pyritz.funcs.CollocationFF(int(len(mc5)/2), 2, derivatives=0)

ts = np.linspace(-1,1,1000)
pts = contour_ff5.evaluate(mc5, ts)
plt.plot(pts[:,0], pts[:,1])

single_pt = contour_ff5.evaluate(mc5, 1)
plt.plot(single_pt[0], single_pt[1], "X")

# %% [markdown]
# #### Minimize over end-points iteratively

# %%
m_nu_s = 24

Nms = np.array( [4, 6] ).astype(int)
Nqs = Nms*10

start_contour_ff = contour_ff4
start_contour_ff_m = mc4
end_contour_ff = contour_ff5
end_contour_ff_m = mc5

def minimize_given_end_points(start_contour_t, end_contour_t):
    start_contour_t = (start_contour_t+1) % 2 - 1
    end_contour_t = (end_contour_t+1) % 2 - 1
    
    x_start = np.concatenate( [e_xa, [0]])
    x_end = np.concatenate( [e_xc, [0]])
    x_start[:2] = start_contour_ff.evaluate(start_contour_ff_m, start_contour_t)
    x_end[:2] = end_contour_ff.evaluate(end_contour_ff_m, end_contour_t)
    
    dim = np.size(x_start)

    m0_path = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nms[0],
                                        exclude_start_point=True, exclude_end_point=True)
    m0_endpoint_rot = np.array([x_start[-1], x_end[-1]])
    m0 = np.concatenate([m0_endpoint_rot, m0_path])

    function_family = pyritz.funcs.CollocationFF(Nms[0], dim, derivatives=1,
                                   fixed_start_point=x_start,
                                   fixed_end_point=x_end)
    quad_scheme = pyritz.quads.Q_clenshaw_curtis

    compute_gradient=False

    nlopt_algorithm = nlopt.LN_NEWUOA
    maxeval = 5000
    xtol_rel = 1e-12

    m = m0

    
    prev_Nm = Nms[0]
    for Nm, Nq in zip(Nms, Nqs):

        Nm, Nq = int(Nm), int(Nq)

        m_path = function_family.change_function_order(m[2:], prev_Nm, Nm, dim)
        m = np.concatenate([m[:2], m_path])
        function_family.set_order(Nm)

        m0_path = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm,
                                            exclude_start_point=True, exclude_end_point=True)
        m0_endpoint_rot = np.array([x_start[-1], x_end[-1]])
        m0 = np.concatenate([m0_endpoint_rot, m0_path])

        ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1,
                                       fixed_start_point=x_start, fixed_end_point=x_end)

        quad_scheme = pyritz.quads.Q_clenshaw_curtis

        compute_gradient=False
        act = pyritz.Action(dim, ff, lagrangian, Nq, quad_scheme,
                            lagrangian_args=compute_gradient)

        def get_path(m):
            m_path = m[2:]
            x_start[-1] = m[0]
            x_end[-1] = m[1]

            ff.set_fixed_start_point(x_start)
            ff.set_fixed_end_point(x_end)
            return m_path

        def get_action(m, grad):
            return act.compute(get_path(m))

        opt = nlopt.opt(nlopt.LN_NEWUOA, np.size(m0))
        opt.set_min_objective(get_action)
        opt.set_xtol_rel(1e-12)
        opt.set_maxeval(10000)
        #opt.set_xtol_abs(1e-1)
        m = opt.optimize(m0)

        acc = act.compute_at_order(get_path(m), Nq*30)
        return acc
        
def get_path(m):
    m_path = m[2:]
    x_start[-1] = m[0]
    x_end[-1] = m[1]

    ff.set_fixed_start_point(x_start)
    ff.set_fixed_end_point(x_end)
    return m_path

def get_action(m, grad):
    return act.compute(get_path(m))

def get_action2(m, grad):
    s = minimize_given_end_points(m[0], m[1])
    print(s, m)
    return s

cm0_start_contour_t = -0.22
cm0_end_contour_t = 1

cm0 = np.array([cm0_start_contour_t,cm0_end_contour_t])
opt = nlopt.opt(nlopt.LN_NEWUOA, np.size(cm0))
opt.set_min_objective(get_action2)
opt.set_xtol_rel(1e-6)
opt.set_maxeval(1000)
cm_start_contour_t, cm_end_contour_t = opt.optimize(cm0)

cm_start_contour_t = (cm_start_contour_t+1) % 2 - 1
cm_end_contour_t = (cm_end_contour_t+1) % 2 - 1

print("start_contour_t=", cm_start_contour_t)
print("end_contour_t=", cm_end_contour_t)
print("S:", minimize_given_end_points(cm_start_contour_t,cm_end_contour_t ))
# Out:
# 6.774746854544457e-07 [-0.22  1.  ]
# 5.300540167207122e-07 [0. 1.]
# 2.0511600194298377e-08 [-0.22  1.22]
# 1.2359680756377362e-06 [-0.44  1.  ]
# 3.3710376388201506e-06 [-0.22  0.78]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-9d9a7f867762> in <module>
#     109 opt.set_xtol_rel(1e-6)
#     110 opt.set_maxeval(1000)
# --> 111 cm_start_contour_t, cm_end_contour_t = opt.optimize(cm0)
#     112
#     113 cm_start_contour_t = (cm_start_contour_t+1) % 2 - 1
#
# ~/scratch/install/lib/python3.7/site-packages/nlopt.py in optimize(self, *args)
#     505
#     506     def optimize(self, *args):
# --> 507         return _nlopt.opt_optimize(self, *args)
#     508
#     509     def last_optimize_result(self):
#
# <ipython-input-87-9d9a7f867762> in get_action2(m, grad)
#      97
#      98 def get_action2(m, grad):
# ...

# %% [markdown]
# ### Iterative gradient-free optimisation

# %%
Nms = np.array( [4] ).astype(int)
Nqs = Nms*10

m_nu_s = 24

start_contour_ff = contour_ff4
start_contour_ff_m = mc4
end_contour_ff = contour_ff5
end_contour_ff_m = mc5

#start_contour_t= -0.580518721968421
#end_contour_t= 0.7654577485620908
#start_contour_t= 0.6777942878290166
#end_contour_t= -0.9618513777915783
start_contour_t = -0.22
end_contour_t = 1

x_start = np.concatenate( [e_xa, [0]])
x_end = np.concatenate( [e_xc, [0]])
x_start[:2] = start_contour_ff.evaluate(start_contour_ff_m, start_contour_t)
x_end[:2] = end_contour_ff.evaluate(end_contour_ff_m, end_contour_t)

m0_path = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nms[0],
                                    exclude_start_point=True, exclude_end_point=True)
m0_endpoint_rot = np.array([x_start[-1], x_end[-1]])
m0 = np.concatenate([m0_endpoint_rot, m0_path])

function_family = pyritz.funcs.CollocationFF(Nms[0], dim, derivatives=1,
                               fixed_start_point=x_start,
                               fixed_end_point=x_end)
quad_scheme = pyritz.quads.Q_clenshaw_curtis

compute_gradient=False

nlopt_algorithm = nlopt.LN_NEWUOA
maxeval = 5000
xtol_rel = 1e-12

m = m0

arch = []
dim = np.size(x_start)
prev_Nm = Nms[0]
for Nm, Nq in zip(Nms, Nqs):
    
    # Select the best m so far
    
    if len(arch) != 0:
        actions = np.array([S for m, S, Nm, Nq in arch])
        m, _, prev_Nm, _ = arch[np.where(actions == np.min(actions))[0][0]]
    
    # Minimize
    
    Nm, Nq = int(Nm), int(Nq)
    
    m_path = function_family.change_function_order(m[2:], prev_Nm, Nm, dim)
    m = np.concatenate([m[:2], m_path])
    function_family.set_order(Nm)

    m0_path = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm,
                                        exclude_start_point=True, exclude_end_point=True)
    m0_endpoint_rot = np.array([x_start[-1], x_end[-1]])
    m0 = np.concatenate([m0_endpoint_rot, m0_path])

    ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1,
                                   fixed_start_point=x_start, fixed_end_point=x_end)

    quad_scheme = pyritz.quads.Q_clenshaw_curtis

    compute_gradient=False
    act = pyritz.Action(dim, ff, lagrangian, Nq, quad_scheme,
                        lagrangian_args=compute_gradient)

    def get_path(m):
        m_path = m[2:]
        x_start[-1] = m[0]
        x_end[-1] = m[1]

        ff.set_fixed_start_point(x_start)
        ff.set_fixed_end_point(x_end)
        return m_path

    def get_action(m, grad):
        return act.compute(get_path(m))

    opt = nlopt.opt(nlopt.LN_NEWUOA, np.size(m0))
    opt.set_min_objective(get_action)
    opt.set_xtol_rel(1e-12)
    opt.set_maxeval(10000)
    #opt.set_xtol_abs(1e-1)
    m = opt.optimize(m0)
    
    S = act.compute(get_path(m))
    
    arch.append( (m, S, Nm, Nq) )
    prev_Nm = Nm

    acc = act.compute_at_order(get_path(m), Nq*30)
    
    print("Nm:", Nm, " Nq:", Nq, "S[m]:", acc, "S_err:", np.abs(acc-S))
# Out:
# Nm: 1  Nq: 10 S[m]: 0.16286142258783257 S_err: 8.954826432228113e-05
# Nm: 2  Nq: 20 S[m]: 0.007713276525994917 S_err: 1.9776832588247473e-08
# Nm: 3  Nq: 30 S[m]: 4.5120919664623645e-05 S_err: 1.401622829572905e-12
# Nm: 4  Nq: 40 S[m]: 6.774713162389861e-07 S_err: 2.2708946963140688e-15
# Nm: 5  Nq: 50 S[m]: 3.4791266691688675e-08 S_err: 2.4400118784296537e-16
# Nm: 6  Nq: 60 S[m]: 2.2903409253368474e-08 S_err: 1.0760880236760043e-15
# Nm: 7  Nq: 70 S[m]: 9.778065710527691e-08 S_err: 6.2248655111021465e-16
# Nm: 8  Nq: 80 S[m]: 3.7933198002113675e-08 S_err: 1.2298485679410402e-15
# Nm: 9  Nq: 90 S[m]: 1.9180161309396e-08 S_err: 1.0095477920961687e-15
# Nm: 10  Nq: 100 S[m]: 8.716306199652335e-08 S_err: 2.6607688476910706e-16

# %%
m, S, Nm, Nq = arch[-1]

print("Nm:", Nm, "Nq:", Nq, "S:", S)
# Out:
# Nm: 8 Nq: 80 S: 170.8113513357493

# %%
m
# Out:
# array([0.29496481, 0.29496463, 0.23848148, 0.25490017, 0.27511098,
#        0.30218854, 0.33814333, 0.38224157, 0.43362289, 0.48688115,
#        0.53329439, 0.56710898, 0.26472249, 0.25147804, 0.22863062,
#        0.19279021, 0.14634024, 0.10096497, 0.06700684, 0.04811962,
#        0.03950367, 0.03555671, 0.29496482, 0.29496481, 0.2949648 ,
#        0.29496475, 0.29496472, 0.29496484, 0.29496478, 0.29496468,
#        0.29496469, 0.29496467])

# %%
s = ""
for mc in ff.get_m_with_fixed_points(get_path(m)):
    s += str(mc) + ", "
s
# Out:
# '0.23118665462998292, 0.23848147940668274, 0.2549001716196076, 0.2751109828607397, 0.3021885437178429, 0.3381433309092949, 0.3822415659134137, 0.4336228884809044, 0.48688115335686566, 0.5332943903693093, 0.5671089826334512, 0.580588, 0.2686477917850299, 0.2647224888205856, 0.25147804022304115, 0.22863062336850873, 0.19279021059334717, 0.1463402356035208, 0.10096497396419736, 0.06700684400202267, 0.048119618243561806, 0.039503665056735485, 0.035556707989126565, 0.0342857, 0.29496480895470106, 0.2949648204883731, 0.29496481056784823, 0.29496480084011223, 0.29496475295753594, 0.29496471669344204, 0.2949648397187014, 0.29496477653585984, 0.294964676197257, 0.2949646867696374, 0.2949646651577413, 0.29496463435136083, '

# %%
float_formatter = lambda x: "%.16f" % x

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1,
                                   fixed_start_point=x_start, fixed_end_point=x_end)
act = pyritz.Action(dim, ff, lagrangian, 5*Nq, quad_scheme,
                    lagrangian_args=compute_gradient)

gl = act.compute_lagrangian(get_path(m))[0]
ts = quad_scheme(5*Nq)[0]

s = ""
for i in range(0,len(gl)):
    s += "{" + str(ts[i]) + ", " + str(float_formatter(gl[i]))+ "},"
"{"+s[:-1]+"}"
# Out:
# '{{-1.0, 0.0000004338935948},{-0.9999879144294304, 0.0000004331777514},{-0.9999516580098436, 0.0000004310356019},{-0.9998912316175987, 0.0000004274832417},{-0.9998066367132705, 0.0000004225473305},{-0.9996978753416145, 0.0000004162648324},{-0.999564950131517, 0.0000004086826895},{-0.999407864295932, 0.0000003998573490},{-0.9992266216318035, 0.0000003898542609},{-0.9990212265199736, 0.0000003787472611},{-0.9987916839250763, 0.0000003666178685},{-0.9985379993954183, 0.0000003535545439},{-0.998260179062844, 0.0000003396518533},{-0.997958229642588, 0.0000003250096068},{-0.9976321584331123, 0.0000003097319379},{-0.9972819733159299, 0.0000002939263464},{-0.9969076827554151, 0.0000002777027213},{-0.9965092957985976, 0.0000002611723513},{-0.9960868220749448, 0.0000002444469249},{-0.9956402717961288, 0.0000002276375355},{-0.9951696557557793, 0.0000002108537043},{-0.9946749853292232, 0.0000001942024319},{-0.9941562724732089, 0.0000001777872676},{-0.9936135297256183, 0.0000001617074439},{-0.993
# ...

# %%
m, _, Nm, Nq, = arch[-1]
get_path(m)

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1, fixed_start_point=x_start, fixed_end_point=x_end)
Nm

# Plot contour of potential

Nq=128
t=np.linspace(-1,1, Nq)
X, Y = np.meshgrid(np.linspace(-1.5, 1.2, 128), np.linspace(-.5, 2, 128))
plt.contour(X, Y, system_pot(X, Y), 256, cmap='gray', linewidths=1, alpha=0.4);

# Plot fixed points

plt.plot(e_xa[0], e_xa[1], 'o', mfc='#14db46', mec='#14db46', ms=8)
plt.plot(e_xb[0], e_xb[1], 'o', mfc='#14db46', mec='#14db46', ms=8)
plt.plot(e_xc[0], e_xc[1], 'o', mfc='#14db46', mec='#14db46', ms=8)
plt.plot(e_xs1[0], e_xs1[1], 'o', mfc='#0000FF', mec='#0000FF', ms=8)
plt.plot(e_xs2[0], e_xs2[1], 'o', mfc='#0000FF', mec='#0000FF', ms=8)

ts = np.linspace(-1,1,1000)
pts = start_contour_ff.evaluate(start_contour_ff_m, ts)
plt.plot(pts[:,0], pts[:,1])

ts = np.linspace(-1,1,1000)
pts = end_contour_ff.evaluate(end_contour_ff_m, ts)
plt.plot(pts[:,0], pts[:,1])

# Plot path

ts = np.linspace(-1, 1, 1000)

paths = [
    #(m0, "Initial", "blue"),
    (m, "Final", ("#ff4b42"))
]

for p in paths:
    _m, _mlabel, _color = p
    _m = get_path(_m)
    xs, vs = ff.evaluate(_m, ts)
    x, y, theta = xs[:, 0], xs[:, 1], xs[:, 2]
    px, py = np.array([np.cos(theta), np.sin(theta)])/10
    
    plt.plot(x, y, label=_mlabel, color=_color, linewidth=2)
    
    arrow_step = 40
    for i in range(len(px)):
        if i%arrow_step==0:
            plt.plot( [x[i],x[i]+px[i]], [y[i],y[i]+py[i]], color="black", alpha=0.6, linewidth=2)

# Plot limits and setup

plt.xlim(-1.3, 1.2);plt.ylim(-.5, 2);
plt.xlabel("$x$", fontsize=22); plt.ylabel("$y$", fontsize=22)
plt.xticks(np.linspace(-1, 1, 5), fontsize=14);
plt.yticks(np.linspace(-0.5, 2, 6), fontsize=14);
plt.gcf().subplots_adjust(bottom=0.15); plt.tight_layout();
#plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(20, 20)

# %%
# Plot path

ts = np.linspace(-1, 1, 1000)

paths = [ (m, "Nm=%d" % Nm, Nm) for m, S, Nm, Nq in arch ]

for p in paths:
    _m, _mlabel, _Nm = p
    _m = get_path(_m)
    xs, vs = ff.evaluate_at_order(_m, ts, _Nm)
    x, y, theta = xs[:, 0], xs[:, 1], xs[:, 2]
    px, py = np.array([np.cos(theta), np.sin(theta)])/10
    
    plt.plot(x, y, label=_mlabel)
    
    arrow_step = 30
    for i in range(len(px)):
        if i%arrow_step==0:
            plt.plot( [x[i],x[i]+px[i]], [y[i],y[i]+py[i]], color="black", alpha=0.6)

# Plot contour of potential

Nq=128
t=np.linspace(-1,1, Nq)
X, Y = np.meshgrid(np.linspace(-1.5, 1.2, 128), np.linspace(-.5, 2, 128))
plt.contour(X, Y, system_pot(X, Y), 256, cmap='gray', linewidths=1, alpha=0.4);

# Plot fixed points

plt.plot(e_xa[0], e_xa[1], 'o', mfc='#AA0000', mec='#AA0000', ms=4)
plt.plot(e_xb[0], e_xb[1], 'o', mfc='#AA0000', mec='#AA0000', ms=4)
plt.plot(e_xc[0], e_xc[1], 'o', mfc='#AA0000', mec='#AA0000', ms=4)
plt.plot(e_xs1[0], e_xs1[1], 'o', mfc='#00AA22', mec='#00AA22', ms=4)
plt.plot(e_xs2[0], e_xs2[1], 'o', mfc='#00AA22', mec='#00AA22', ms=4)

# Plot limits and setup

plt.xlim(-1.3, 1.2);plt.ylim(-.5, 2);
plt.xlabel("$x$", fontsize=22); plt.ylabel("$y$", fontsize=22)
plt.xticks(np.linspace(-1, 1, 5), fontsize=14);
plt.yticks(np.linspace(-0.5, 2, 6), fontsize=14);
plt.gcf().subplots_adjust(bottom=0.15); plt.tight_layout();
plt.legend()

ts = np.linspace(-1,1,1000)
pts = start_contour_ff.evaluate(start_contour_ff_m, ts)
plt.plot(pts[:,0], pts[:,1])

ts = np.linspace(-1,1,1000)
pts = end_contour_ff.evaluate(end_contour_ff_m, ts)
plt.plot(pts[:,0], pts[:,1])

fig = mpl.pyplot.gcf()
fig.set_size_inches(8, 8)

# %% [markdown]
# ### Nu_s

# %%
Nm = 20
Nq = Nm*10

#m_nu_ss = np.array([0,1,2,30]).astype(int)
m_nu_ss = np.arange(0, 110, 2).astype(int)

x_start = np.concatenate( [e_xa, [0]])
x_end = np.concatenate( [e_xc, [0]])

m_path = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm,
                                    exclude_start_point=True, exclude_end_point=True)
m_endpoint_rot = np.array([x_start[-1], x_end[-1]])
m = np.concatenate([m_endpoint_rot, m_path])

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1,
                               fixed_start_point=x_start,
                               fixed_end_point=x_end)
quad_scheme = pyritz.quads.Q_clenshaw_curtis

compute_gradient=False
act = pyritz.Action(dim, ff, lagrangian, Nq, quad_scheme,
                    lagrangian_args=compute_gradient)



nlopt_algorithm = nlopt.LN_NEWUOA
maxeval = 5000
xtol_rel = 1e-12

arch = []
dim = np.size(x_start)

for nu in m_nu_ss:
    m_nu_s = nu
    
    def get_path(m):
        m_path = m[2:]
        x_start[-1] = m[0]
        x_end[-1] = m[1]

        ff.set_fixed_start_point(x_start)
        ff.set_fixed_end_point(x_end)
        return m_path

    def get_action(m, grad):
        return act.compute(get_path(m))

    opt = nlopt.opt(nlopt.LN_NEWUOA, np.size(m))
    opt.set_min_objective(get_action)
    opt.set_xtol_rel(1e-5)
    #opt.set_maxeval(5000)
    m = opt.optimize(m)
    
    acc = act.compute_at_order(get_path(m), Nq*30)
    S = act.compute(get_path(m))
    
    arch.append( (m_nu_s, Nm, Nq, S, m) )
    
    print("nu_s:", m_nu_s, "Nm:", Nm, " Nq:", Nq, "S[m]:", acc, "S_err:", np.abs(acc-S))

# %%
s = ""
for mc in ff.get_m_with_fixed_points(get_path(m)):
    s += str(mc) + ", "
s

# %%
m_nu_sm, Nm, Nq, S, m = arch[40]

print("nu:", m_nu_sm, "Nm:", Nm, "Nq:", Nq, "S:", S)

# %%
# Plot path

ts = np.linspace(-1, 1, 1000)

paths = [
    #(m0, "Initial", "blue"),
    (m, "Final", ("#ff4b42"))
]

for p in paths:
    _m, _mlabel, _color = p
    _m = get_path(_m)
    xs, vs = ff.evaluate(_m, ts)
    x, y, theta = xs[:, 0], xs[:, 1], xs[:, 2]
    px, py = np.array([np.cos(theta), np.sin(theta)])/10
    
    plt.plot(x, y, label=_mlabel, color=_color, linewidth=2)
    
    arrow_step = 40
    for i in range(len(px)):
        if i%arrow_step==0:
            plt.plot( [x[i],x[i]+px[i]], [y[i],y[i]+py[i]], color="black", alpha=0.6, linewidth=2)

# Plot contour of potential

Nq=128
t=np.linspace(-1,1, Nq)
X, Y = np.meshgrid(np.linspace(-1.5, 1.2, 128), np.linspace(-.5, 2, 128))
plt.contour(X, Y, system_pot(X, Y), 256, cmap='gray', linewidths=1, alpha=0.4);

# Plot fixed points

plt.plot(e_xa[0], e_xa[1], 'o', mfc='#14db46', mec='#14db46', ms=8)
plt.plot(e_xb[0], e_xb[1], 'o', mfc='#14db46', mec='#14db46', ms=8)
plt.plot(e_xc[0], e_xc[1], 'o', mfc='#14db46', mec='#14db46', ms=8)
plt.plot(e_xs1[0], e_xs1[1], 'o', mfc='#0000FF', mec='#0000FF', ms=8)
plt.plot(e_xs2[0], e_xs2[1], 'o', mfc='#0000FF', mec='#0000FF', ms=8)

# Plot limits and setup

plt.xlim(-1.3, 1.2);plt.ylim(-.5, 2);
plt.xlabel("$x$", fontsize=22); plt.ylabel("$y$", fontsize=22)
plt.xticks(np.linspace(-1, 1, 5), fontsize=14);
plt.yticks(np.linspace(-0.5, 2, 6), fontsize=14);
plt.gcf().subplots_adjust(bottom=0.15); plt.tight_layout();
#plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(20, 20)

print(m_nu_s_m)

# %%
act = pyritz.Action(dim, ff, lagrangian, 5*Nq, quad_scheme,
                    lagrangian_args=compute_gradient)

gl = act.compute_lagrangian(get_path(m))[0]
ts = quad_scheme(5*Nq)[0]

s = ""
for i in range(0,len(gl)):
    s += "{" + str(ts[i]) + ", " + str(gl[i])+ "},"
"{"+s+"}"

# %%
plt.plot(act.compute_lagrangian(get_path(m))[0])

# %%
s=""
for m_nu_sm, Nm, Nq, S, m in arch:
    s+="{%d, %f}," % (m_nu_sm, S)
s

# %% [markdown]
# ### Gradient optimisation

# %%
m_nu_s = 100

x_start = np.concatenate( [e_xa, [0]])
x_end = np.concatenate( [e_xc, [0]])

Nm = 10
Nq = Nm*10

m0_path = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm,
                                    exclude_start_point=True, exclude_end_point=True)
m0_endpoint_rot = np.array([x_start[-1], x_end[-1]])
m0 = np.concatenate([m0_endpoint_rot, m0_path])

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1,
                               fixed_start_point=x_start, fixed_end_point=x_end)

quad_scheme = pyritz.quads.Q_clenshaw_curtis

compute_gradient=True
act = pyritz.Action(dim, ff, lagrangian, Nq, quad_scheme,
                    lagrangian_args=compute_gradient)

def get_path(m):
    m_path = m[2:]
    x_start[-1] = m[0]
    x_end[-1] = m[1]
    
    ff.set_fixed_start_point(x_start)
    ff.set_fixed_end_point(x_end)
    return m_path

def get_action(m, grad):
    m_path = get_path(m)
    
    if grad.size > 0:
        grad[0] = 0
        grad[1] = 0
        
        return act.compute(m_path, grad[2:])
    else:
        return act.compute(m_path)

opt = nlopt.opt(nlopt.LD_MMA, np.size(m0))
opt.set_min_objective(get_action)
opt.set_xtol_rel(1e-12)
opt.set_maxeval(1000)
m = opt.optimize(m0)

print(act.compute(get_path(m0)))
print(act.compute(get_path(m)))

# %%
# Plot path

ts = np.linspace(-1, 1, 1000)

paths = [
    (m0, "Initial", "blue"),
    (m, "Final", "green")
]

for p in paths:
    _m, _mlabel, _color = p
    _m = get_path(_m)
    xs, vs = ff.evaluate(_m, ts)
    x, y, theta = xs[:, 0], xs[:, 1], xs[:, 2]
    px, py = np.array([np.cos(theta), np.sin(theta)])/10
    
    plt.plot(x, y, label=_mlabel, color=_color)
    
    arrow_step = 30
    for i in range(len(px)):
        if i%arrow_step==0:
            plt.plot( [x[i],x[i]+px[i]], [y[i],y[i]+py[i]], color="black", alpha=0.6)

# Plot contour of potential

Nq=128
t=np.linspace(-1,1, Nq)
X, Y = np.meshgrid(np.linspace(-1.5, 1.2, 128), np.linspace(-.5, 2, 128))
plt.contour(X, Y, system_pot(X, Y), 256, cmap='gray', linewidths=1, alpha=0.4);

# Plot fixed points

plt.plot(e_xa[0], e_xa[1], 'o', mfc='#AA0000', mec='#AA0000', ms=4)
plt.plot(e_xb[0], e_xb[1], 'o', mfc='#AA0000', mec='#AA0000', ms=4)
plt.plot(e_xc[0], e_xc[1], 'o', mfc='#AA0000', mec='#AA0000', ms=4)
plt.plot(e_xs1[0], e_xs1[1], 'o', mfc='#00AA22', mec='#00AA22', ms=4)
plt.plot(e_xs2[0], e_xs2[1], 'o', mfc='#00AA22', mec='#00AA22', ms=4)

# Plot limits and setup

plt.xlim(-1.3, 1.2);plt.ylim(-.5, 2);
plt.xlabel("$x$", fontsize=22); plt.ylabel("$y$", fontsize=22)
plt.xticks(np.linspace(-1, 1, 5), fontsize=14);
plt.yticks(np.linspace(-0.5, 2, 6), fontsize=14);
plt.gcf().subplots_adjust(bottom=0.15); plt.tight_layout();
plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(8, 8)
