# %% [markdown]
# # Multi-limit cycle Van der Pol oscillator (MLC-VdPo)
#
# **Lagrangian:** Geometric Action
# <br>
# **Implementation:** Python
#
# **System:**
#
# $ \begin{cases}
# du = (u - u^3 - \beta u v^2)\ dt + \sqrt{\epsilon}\ dW_u \\
# dv = -(1 + u^2) v\ dt + \sqrt{\epsilon}\ dW_v
# \end{cases}$

# %%
sfdir = !pwd
sfdir = "/".join(sfdir[0].split("/")[:-3]) + "/"
import sys
sys.path.insert(0, sfdir+'pyritz/')

import pyritz
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import nlopt

# %% [markdown]
# ## System

# %% [markdown]
# ### Parameters

# %% [markdown]
# System parameters are defined here. All system parameter variables are prefaced with "m_", with the exception of `dim` which is the dimension of the system.

# %%
dim = 2

m_r1 = 1
m_r2 = 3
m_r3 = 4
m_c = 0.25

# %% [markdown]
# ### Dynamics
#
# `system_a` is the drift term of the system. It's used for plotting stream-plots, as well as finding fixed points of the deterministic system.
#
# `lagrangian` is the Lagrangian of the system. The Lagrangian used is the Geometric Action lagrangian (Heymann and Vanden-Eijnden), defined as
#
# $$
# L(x, \dot x) = |\dot x| |a(x)| - \dot x \cdot a(x)
# $$
#
# for any general Ito diffusion of the form
#
# $$
# dX = a(X)dt + \sqrt{\epsilon} dW.
# $$
#
# The function also computes the partial derivatives of the Lagrangian, which are used for gradient optimisation. This can be enabled/disabled by setting the *args* argument to True/False. The partial derivatives of the geometric lagrangian are
#
# $$\begin{aligned}
# \frac{\partial L}{\partial x} & = \nabla a( x ) \cdot \left( |\dot x| \hat{a}(x) - \dot x \right) \\
# \frac{\partial L}{\partial \dot x} & = |a(x)| \hat{\dot{x}} - a(x)
# \end{aligned}$$
#
# An important property of the geometric action is that it is time-reparameterisation invariant, meaning that $x$ can be replaced by any other path that shares the same *graph*.

# %% [markdown]
# #### Notes on the Maier-Stein system
#
# Let $(\nabla a)_{ij} = \frac{\partial a_i}{\partial x_j}$, where $x = (u, v)$, then
#
# $$
# \nabla a = \begin{pmatrix}
#     1 - 3 u^2 - \beta v^2 &  -2 u v \\
#     - 2 \beta u v & - (1 + u^2)
# \end{pmatrix}
# $$

# %%
-((y*(x**2 + 2*y**2))/np.sqrt(x**2 + y**2)) + (x*(-1 - x**2/(x**2 + y**2))*(-4 + np.sqrt(x**2 + y**2))*(-3 + np.sqrt(x**2 + y**2))*(-1 + np.sqrt(x**2 + y**2)))/4.,
x*np.sqrt(x**2 + y**2)*(1 + y**2/(x**2 + y**2)) + (y*(-1 - x**2/(x**2 + y**2))*(-4 + np.sqrt(x**2 + y**2))*(-3 + np.sqrt(x**2 + y**2))*(-1 + np.sqrt(x**2 + y**2)))/4.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7d977fa3b01c> in <module>
# ----> 1 -((y*(x**2 + 2*y**2))/np.sqrt(x**2 + y**2)) + (x*(-1 - x**2/(x**2 + y**2))*(-4 + np.sqrt(x**2 + y**2))*(-3 + np.sqrt(x**2 + y**2))*(-1 + np.sqrt(x**2 + y**2)))/4.,
#       2 x*np.sqrt(x**2 + y**2)*(1 + y**2/(x**2 + y**2)) + (y*(-1 - x**2/(x**2 + y**2))*(-4 + np.sqrt(x**2 + y**2))*(-3 + np.sqrt(x**2 + y**2))*(-1 + np.sqrt(x**2 + y**2)))/4.
#
# NameError: name 'y' is not defined

# %%
def system_a(r, th):
    return np.array([
        -m_c*(1 + np.cos(th)**2)*(r - m_r1)*(r - m_r2)*(r - m_r3)*r,
        r*(1 + np.sin(th)**2)
    ])

def system_a_cartesian(x, y):
    return np.array([
        -((y*(x**2 + 2*y**2))/np.sqrt(x**2 + y**2)) + (x*(-1 - x**2/(x**2 + y**2))*(-4 + np.sqrt(x**2 + y**2))*(-3 + np.sqrt(x**2 + y**2))*(-1 + np.sqrt(x**2 + y**2)))/4.,
x*np.sqrt(x**2 + y**2)*(1 + y**2/(x**2 + y**2)) + (y*(-1 - x**2/(x**2 + y**2))*(-4 + np.sqrt(x**2 + y**2))*(-3 + np.sqrt(x**2 + y**2))*(-1 + np.sqrt(x**2 + y**2)))/4.
    ])

def lagrangian(ls, dxls, dvls, fvals, ts, args):
    compute_gradient = args
    
    xs, dxs = fvals
    rs, ths = xs[:, 0], xs[:, 1]
    drs, dths = dxs[:, 0], dxs[:, 1]
    
    ars = -m_c*(1+np.cos(ths)**2)*(rs - m_r1)*(rs - m_r2)*(rs - m_r3)*rs
    aths = rs*(1+np.sin(ths)**2)
    aas = np.array( [ars, aths] )
    
    dxs_norm = np.linalg.norm(dxs, axis=1)
    a_norm = np.sqrt(ars**2 + aths**2)
    dxs_dot_a = ars*dxs[:,0] + aths*dxs[:, 1]
    
    ls[:] = dxs_norm * a_norm - dxs_dot_a
    
    # Compute gradient
    
    if compute_gradient:

        ## Compute dL/dx

        da = np.zeros( (2, 2, len(ts)) )
        da[0,0] = -((4*rs**3 - m_r1*m_r2*m_r3 - 3*rs**2*(m_r1 + m_r2 + m_r3) + 2*rs*(m_r2*m_r3 + m_r1*(m_r2 + m_r3)))*(3 + np.cos(2*ths)))/8.
        da[0,1] = 1 + np.sin(ths)**2
        da[1,0] = (rs*(rs - m_r1)*(rs - m_r2)*(rs - m_r3)*np.sin(2*ths))/4.
        da[1,1] = rs*np.sin(2*ths)
        
        a_normalized = aas/a_norm

        a_normalized[:, np.where(a_norm==0)] = 0 # Set zero-norm vectors to 0

        for i in range(dxls.shape[0]):
            dxls[i, :] = da[:,:,i].dot( dxs_norm[i]*a_normalized[:,i] - dxs[i,:])

        ## Compute dL/dv

        dxs_2 = (dxs.T*(a_norm/dxs_norm)).T
        dxs_2[ np.where(dxs_norm==0),:] = 0

        dvls[:] = dxs_2 - aas.T

# %% [markdown]
# ## Optimisation

# %% [markdown]
# ### Gradient-free optimisation

# %%
x_start = np.array([1, 0])
x_end = np.array([3, 30])
#x_end = np.array([3.999, 0])

Nm = 20
Nq = Nm*10

m0_path = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm,
                                    exclude_start_point=True, exclude_end_point=True)

m0_path[:Nm] += np.random.random(Nm)/10
m0_path[Nm:] += np.random.random(Nm)/10

m0 = np.concatenate( [ [x_start[1], x_end[1]], m0_path ] )

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1,
                               fixed_start_point=x_start,
                               fixed_end_point=x_end)

quad_scheme = pyritz.quads.Q_clenshaw_curtis

compute_gradient=False
act = pyritz.Action(dim, ff, lagrangian, Nq, quad_scheme, lagrangian_args=compute_gradient)

def get_action(m, grad):
    m_path = m[2:]
    x_start[1] = m[0]
    x_end[1] = m[1]
    ff.set_fixed_start_point( x_start )
    ff.set_fixed_end_point( x_end )
    
    return act.compute(m_path)

opt = nlopt.opt(nlopt.LN_NEWUOA, np.size(m0))
opt.set_min_objective(get_action)
opt.set_xtol_rel(1e-12)
opt.set_maxeval(10000)
m = opt.optimize(m0)

x_start[1] = m0[0]
x_end[1] = m0[1]
ff.set_fixed_start_point( x_start )
ff.set_fixed_end_point( x_end )
print(act.compute(m0[2:]))
x_start[1] = m[0]
x_end[1] = m[1]
ff.set_fixed_start_point( x_start )
ff.set_fixed_end_point( x_end )
print(act.compute(m[2:]))
# Out:
# /store/SOFT/ltk26/dev/softbridge/pyritz/pyritz/funcs/collocation_ff.py:175: RuntimeWarning: divide by zero encountered in double_scalars
#   s += omegas[k] / (ts[i] - self.chebyshev_ts[k] )
# 8.937021960214576
# 3.652670262597078

# %%
x_start = np.array([1, 0])
#x_end = np.array([3.999, 0])
x_end = np.array([3, 0])

Nm = 20
Nq = Nm*10

#m0_path = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm,
#                                    exclude_start_point=True, exclude_end_point=True)

#m0_path[:Nm] += np.random.random(Nm)/10
#m0_path[Nm:] += np.random.random(Nm)/10

#m0 = np.concatenate( [ [x_end[1]], m0_path ] )
m0 = np.array(m)
m0[1:Nm+1] += np.random.random(Nm)/20
m0[1+Nm:] += np.random.random(Nm)/20

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1,
                               fixed_start_point=x_start,
                               fixed_end_point=x_end)

quad_scheme = pyritz.quads.Q_clenshaw_curtis

compute_gradient=False
act = pyritz.Action(dim, ff, lagrangian, Nq, quad_scheme, lagrangian_args=compute_gradient)

def get_action(m, grad):
    m_path = m[1:]
    x_end[1] = m[0]
    ff.set_fixed_end_point( x_end )
    
    return act.compute(m_path)

opt = nlopt.opt(nlopt.LN_NEWUOA, np.size(m0))
opt.set_min_objective(get_action)
opt.set_xtol_rel(1e-12)
opt.set_maxeval(10000)
m = opt.optimize(m0)

x_start[1] = m0[0]
x_end[1] = m0[1]
ff.set_fixed_start_point( x_start )
ff.set_fixed_end_point( x_end )
print(act.compute(m0[2:]))
x_start[1] = m[0]
x_end[1] = m[1]
ff.set_fixed_start_point( x_start )
ff.set_fixed_end_point( x_end )
print(act.compute(m[2:]))
# Out:
# 3.7067850215553957
# 3.6509161185701258

# %% [markdown]
# #### Instanton plot

# %%
ts = np.linspace(-1, 1, 1000)

paths = [
    (m0, "Initial"),
    (m, "Final")
]

for p in paths:
    _m, _mlabel = p
    x_start[1] = _m[0]
    x_end[1] = _m[1]
    ff.set_fixed_start_point( x_start )
    ff.set_fixed_end_point( x_end )
    xs, vs = ff.evaluate(_m[2:], ts)
    plt.plot(xs[:,0], xs[:,1], label=_mlabel)

X, Y = np.meshgrid(np.linspace(0, 4.2,64), np.linspace(0,x_end[1]+1,64))
vx,vy=system_a(X,Y); #vx=vx/np.sqrt(vx**2+vy**2); vy=vy/np.sqrt(vx**2+vy**2)
plt.streamplot(X,Y, vx, vy, density=1.7, linewidth=.6, color='gray');
plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(10, 10)

# %% [markdown]
# ### Gradient optimisation

# %%
x_start = np.array([1, 0])
x_end = np.array([3, 30])
#x_end = np.array([3.999, 0])

Nm = 15
Nq = Nm*10

m0 = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm)

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1)

quad_scheme = pyritz.quads.Q_clenshaw_curtis

compute_gradient=True
act = pyritz.Action(dim, ff, lagrangian, Nq, quad_scheme, lagrangian_args=compute_gradient)

ub = np.full(dim*Nm, np.inf)
lb = np.full(dim*Nm, -np.inf)

tol = 1e-10

for i in range(dim):
    ub[i*Nm] = x_start[i] + tol
    lb[i*Nm] = x_start[i] - tol
    ub[Nm-1 + i*Nm] = x_end[i] + tol
    lb[Nm-1 + i*Nm] = x_end[i] - tol
    
ub[2*Nm-1]= np.inf
lb[2*Nm-1]= -np.inf

def get_action(m, grad):
    if grad.size > 0:
        grad[0] = grad[Nm] = grad[Nm-1] = 0 
        return act.compute(m, grad)
    else:
        return act.compute(m)

opt = nlopt.opt(nlopt.LD_SLSQP, np.size(m0))
opt.set_lower_bounds(lb)
opt.set_upper_bounds(ub)
opt.set_min_objective(get_action)
opt.set_xtol_rel(1e-12)
opt.set_maxeval(5000)
m = opt.optimize(m0)

print(act.compute(m0))
print(act.compute(m))
# Out:
# 4.122029356281832
# 2.5337652154929238

# %%
ts = np.linspace(-1, 1, 1000)

paths = [
    (m0, "Initial"),
    (m, "Final")
]

for p in paths:
    _m, _mlabel = p
    xs, vs = ff.evaluate(_m, ts)
    plt.plot(xs[:,0], xs[:,1], label=_mlabel)

X, Y = np.meshgrid(np.linspace(0, 4.2,64), np.linspace(0,x_end[1]+1,64))
vx,vy=system_a(X,Y); #vx=vx/np.sqrt(vx**2+vy**2); vy=vy/np.sqrt(vx**2+vy**2)
plt.streamplot(X,Y, vx, vy, density=1.7, linewidth=.6, color='gray');
plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(10, 10)

# %% [markdown]
# ### Iterative gradient optimisation

# %%
old_Nm = 16
new_Nm = 18

ts = pyritz.funcs.CollocationFF.get_chebyshev_nodes(new_Nm)
m2 = ff.evaluate(m, ts)[0].T.flatten()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a639c187ae37> in <module>
#       3
#       4 ts = pyritz.funcs.CollocationFF.get_chebyshev_nodes(new_Nm)
# ----> 5 m2 = ff.evaluate(m, ts)[0].T.flatten()
#
# NameError: name 'ff' is not defined

# %%
m2 =m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f87dc07a87ff> in <module>
# ----> 1 m2 =m
#
# NameError: name 'm' is not defined

# %%
x_start = np.array([1, 0])
x_end = np.array([3, 20])

Nm = 4
Nq = Nm*10

m0 = pyritz.funcs.CollocationFF.get_straight_line_path(x_start, x_end, Nm)
#m0 = np.array(m2)
m0[Nm:] = 4*m0[Nm:]
m0[Nm] = 0
x_start[1] = m0[Nm]

ff = pyritz.funcs.CollocationFF(Nm, dim, derivatives=1)

quad_scheme = pyritz.quads.Q_clenshaw_curtis

compute_gradient=True
act = pyritz.Action(dim, ff, lagrangian, Nq, quad_scheme, lagrangian_args=compute_gradient)

ub = np.full(dim*Nm, np.inf)
lb = np.full(dim*Nm, -np.inf)

tol = 1e-10

for i in range(dim):
    ub[i*Nm] = x_start[i] + tol
    lb[i*Nm] = x_start[i] - tol
    ub[Nm-1 + i*Nm] = x_end[i] + tol
    lb[Nm-1 + i*Nm] = x_end[i] - tol
    
ub[2*Nm-1]= np.inf
lb[2*Nm-1]= -np.inf

def get_action(m, grad):
    if grad.size > 0:
        grad[0] = grad[Nm] = grad[Nm-1] = 0 
        return act.compute(m, grad)
    else:
        return act.compute(m)

opt = nlopt.opt(nlopt.LD_SLSQP, np.size(m0))
opt.set_lower_bounds(lb)
opt.set_upper_bounds(ub)
opt.set_min_objective(get_action)
opt.set_xtol_rel(1e-12)
opt.set_maxeval(5000)
m = opt.optimize(m0)

print(act.compute(m0))
print(act.compute(m))
# Out:
# /store/SOFT/ltk26/dev/softbridge/pyritz/pyritz/funcs/collocation_ff.py:184: RuntimeWarning: divide by zero encountered in double_scalars
#   s += omegas[k] / (ts[i] - self.chebyshev_ts[k] )

# %%
ts = np.linspace(-1, 1, 1000)

paths = [
    (m0, "Initial"),
    (m, "Final")
]

for p in paths:
    _m, _mlabel = p
    xs, vs = ff.evaluate(_m, ts)
    plt.plot(xs[:,0], xs[:,1], label=_mlabel)

X, Y = np.meshgrid(np.linspace(0, 4.2,64), np.linspace(0,100,64))
vx,vy=system_a(X,Y); #vx=vx/np.sqrt(vx**2+vy**2); vy=vy/np.sqrt(vx**2+vy**2)
plt.streamplot(X,Y, vx, vy, density=1.7, linewidth=.6, color='gray');
plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(7, 6)

# %%
def polar_to_cartesian(r, theta):
    x = r * np.cos(theta)
    y = r * np.sin(theta)
    return x, y

ts = np.linspace(-1, 1, 10000)

pxs, ths = ff.evaluate(m, ts)
xs, ys = polar_to_cartesian(pxs[:, 0], pxs[:, 1])
plt.plot(xs, ys)

X, Y = np.meshgrid(np.linspace(-4.2, 4.2,64), np.linspace(-4.2, 4.2,64))
vx,vy=system_a_cartesian(X,Y); #vx=vx/np.sqrt(vx**2+vy**2); vy=vy/np.sqrt(vx**2+vy**2)
plt.streamplot(X,Y, vx, vy, density=1.7, linewidth=.6, color='gray');
plt.legend()

fig = mpl.pyplot.gcf()
fig.set_size_inches(7, 7)
# Out:
# No handles with labels found to put in legend.

# %%
for n in xs[:,0]:
    print(str(n) + ",")
# Out:
# 0.9999999999,
# 1.0000059202234866,
# 1.0000132028976856,
# 1.000021426402648,
# 1.000030201518417,
# 1.0000391706828524,
# 1.000048007355329,
# 1.0000564153862788,
# 1.0000641283925096,
# 1.0000709091382793,
# 1.0000765489220635,
# 1.0000808669689865,
# 1.0000837098288753,
# 1.0000849507798937,
# 1.000084489237721,
# 1.000082250170244,
# 1.0000781835177206,
# 1.0000722636183867,
# 1.0000644886394738,
# 1.0000548800136022,
# 1.0000434818805248,
# 1.0000303605341891,
# 1.0000156038750925,
# 0.9999993208678987,
# 0.9999816410042967,
# 0.9999627137710689,
# 0.999942708123352,
# 0.9999218119630608,
# 0.9999002316224547,
# 0.9998781913528286,
# 0.9998559328183002,
# 0.9998337145946795,
# 0.999811811673395,
# 0.999790514970468,
# 0.9997701308404997,
# 0.999750980595672,
# 0.9997334000297318,
# 0.9997177389469457,
# 0.9997043606960156,
# 0.9996936417089253,
# 0.9996859710447186,
# 0.9996817499381845,
# 0.9996813913534376,
# 0.9996853195423826,
# 0.9996939696080442,
# 0.9997077870727555,
# 0.9997272274511867,
# 0.9997527558282052,
# 0.9997848464415554,
# 0.9998239822693428,
# 0.9998706546223116,
# 0.9999253627409137,
# 0.9999886133971377,
# 1.0000609205011133,
# 1.000142804712455,
# 1.0002347930563527,
# 1.000337418544394,
# 1.0004512198000952,
# 1.0005767406891597,
# 1.000714529954415,
# 1.000865140855461,
# 1.0010291308129786,
# 1.0012070610577184,
# 1.001399496284151,
# 1.0016070043087593,
# 1.0018301557329756,
# 1.0020695236107509,
# 1.0023256831207417,
# 1.0025992112431072,
# 1.00289068644091,
# 1.0032006883461035,
# 1.0035297974501065,
# 1.003878594798938,
# 1.0042476616929237,
# 1.0046375793909454,
# 1.005048928819228,
# 1.0054822902846643,
# 1.0059382431926478,
# 1.006417365769418,
# 1.0069202347889037,
# 1.0074474253040449,
# 1.0079995103825914,
# 1.0085770608473685,
# 1.009180645020983,
# 1.0098108284749767,
# 1.0104681737833991,
# 1.0111532402807974,
# 1.0118665838246093,
# 1.0126087565619377,
# 1.0133803067007108,
# 1.014181778285192,
# 1.0150137109758508,
# 1.0158766398335566,
# 1.0167710951081037,
# 1.0176976020310349,
# 1.018656680612761,
# 1.0196488454439572,
# 1.0206746055012188,
# 1.0217344639569654,
# 1.0228289179935772,
# 1.0239584586217418,
# 1.0251235705030068,
